# %% [markdown]
# # BioClip Training

# %%
# (Optional) Install required packages if not present.
# Uncomment and run the next line in the notebook if you need to install dependencies.
# !pip install open_clip_torch pillow pandas requests

# %%
# Imports and model setup
import open_clip
import torch
from PIL import Image
import pandas as pd
import requests
from io import BytesIO
import time
import unicodedata
from typing import Optional, Dict, List

# Load BioCLIP model and transforms (imageomics/bioclip)
# This may download weights the first time you run it.
model, preprocess_train, preprocess_val = open_clip.create_model_and_transforms('hf-hub:imageomics/bioclip')
tokenizer = open_clip.get_tokenizer('hf-hub:imageomics/bioclip')
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = model.to(device)
model.eval()
# Out:
# CLIP(
#   (visual): VisionTransformer(
#     (conv1): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16), bias=False)
#     (patch_dropout): Identity()
#     (ln_pre): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (transformer): Transformer(
#       (resblocks): ModuleList(
#         (0-11): 12 x ResidualAttentionBlock(
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (ls_1): Identity()
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Sequential(
#             (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#             (gelu): GELU(approximate='none')
#             (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (ls_2): Identity()
#         )
#       )
#     )
#     (ln_post): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (transformer): Transformer(
#     (resblocks): ModuleList(
#       (0-11): 12 x ResidualAttentionBlock(
#         (ln_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ls_1): Identity()
#         (ln_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (c_fc): Linear(in_features=512, out_features=2048, bias=True)
#           (gelu): GELU(approximate='none')
#           (c_proj): Linear(in_features=2048, out_features=512, bias=True)
#         )
#         (ls_2): Identity()
#       )
#     )
#   )
#   (token_embedding): Embedding(49408, 512)
#   (ln_final): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
# )

# %%
# Load and clean plant names from CSV
plant_df = pd.read_csv('data/Plants_Formatted.csv', encoding='latin-1')

import re

def clean_scientific_name(s: str) -> str:
    """Normalize scientific names and remove cultivar/variety details.

    Follows the same intent as the project's `wikipediaApi.ts`:
    - Removes cultivar text in single quotes
    - Removes hybrid markers like " x "
    - Removes variety/subspecies markers (var., subsp., sub., forma)
    - If string contains ' sp.' or 'unknown', reduce to genus only
    - Normalize unicode and collapse whitespace
    """
    if not isinstance(s, str):
        s = str(s)
    s = s.strip()
    if not s:
        return s

    # Normalize unicode (remove accents)
    s = unicodedata.normalize('NFKD', s)
    s = ''.join(ch for ch in s if not unicodedata.combining(ch))

    # Remove weird replacement characters
    s = s.replace('\u2019', "'").replace('\u201c', '"').replace('\u201d', '"')

    # Remove any trailing or internal newlines
    s = s.replace('\n', ' ').replace('\r', ' ').strip()

    # Remove cultivar names in single quotes: "Genus species 'Cultivar'" -> "Genus species"
    if "'" in s:
        # remove the quote and everything after the first quote occurrence
        s = s.split("'")[0].strip()

    # Remove hybrid markers like ' x '
    if ' x ' in s:
        s = s.split(' x ')[0].strip()

    # Remove variety/subspecies markers
    markers = [' var. ', ' subsp. ', ' sub. ', ' forma ', ' f. ']
    for marker in markers:
        if marker in s:
            s = s.split(marker)[0].strip()

    # Handle 'sp.' or 'sp ' or 'unknown' -> return genus only
    if ' sp.' in s or re.search(r'\bsp\b', s, flags=re.IGNORECASE) or 'unknown' in s.lower():
        parts = s.split()
        s = parts[0] if parts else s

    # Collapse multiple spaces
    s = ' '.join(s.split())

    return s

# Some rows may have empty Scientific Name cells; drop those
plant_df['Scientific Name'] = plant_df['Scientific Name'].fillna('').astype(str)
all_names = [clean_scientific_name(x) for x in plant_df['Scientific Name'].tolist() if x.strip()!='']
# Deduplicate while preserving order
seen = set()
plant_names = []
# Keep a mapping to original names too (for evaluation display)
original_map = {}
for orig_raw in plant_df['Scientific Name'].tolist():
    orig = str(orig_raw) if not pd.isna(orig_raw) else ''
    cleaned = clean_scientific_name(orig)
    if cleaned and cleaned not in seen:
        seen.add(cleaned)
        plant_names.append(cleaned)
        original_map[cleaned] = orig

print(f'Unique species to evaluate: {len(plant_names)}')
plant_names[:10]
# Out:
# Unique species to evaluate: 349
# ['Adiantum peruvianum',
#  'Adiantum raddianum',
#  'Adiantum ternerum',
#  'Adiantum trapeziforme',
#  'Aechmea',
#  'Aechmea blanchetiana',
#  'Aechmea chantinii',
#  'Aechmea fasciata',
#  'Aechmea fulgens',
#  'Aechmea gamosepala']

# %%
# Load and preprocess your image
image = Image.open('data/example_images/Adiantum-peruvianum-Silver-Dollar-Fern-Amazon-Spheres.jpg.webp')
image = preprocess_val(image).unsqueeze(0).to(device)
image
# Out:
# tensor([[[[-1.6171, -1.6755, -1.6755,  ..., -1.2959, -1.2375, -1.1499],
#           [-1.6901, -1.7485, -1.7193,  ..., -1.0039, -1.2375, -1.1353],
#           [-1.7339, -1.7631, -1.7047,  ..., -0.3032, -0.4492, -1.1353],
#           ...,
#           [-1.3105, -1.3105, -1.2521,  ..., -0.7266, -0.6098, -0.1280],
#           [-1.3397, -1.3251, -1.3251,  ..., -0.6390, -0.4930, -0.2740],
#           [-1.2667, -1.3251, -1.2083,  ..., -0.4930, -0.4054, -0.1134]],
#
#          [[-1.4369, -1.4970, -1.4970,  ..., -1.1668, -1.1518, -1.0918],
#           [-1.5120, -1.5870, -1.5720,  ..., -0.6415, -1.1068, -1.0918],
#           [-1.5570, -1.6170, -1.5720,  ...,  0.0488, -0.2363, -1.0918],
#           ...,
#           [-1.2568, -1.2568, -1.1968,  ..., -0.5965, -0.4614,  0.0338],
#           [-1.2718, -1.2718, -1.2718,  ..., -0.5065, -0.3564, -0.1313],
#           [-1.1668, -1.2418, -1.1368,  ..., -0.3564, -0.2513,  0.0488]],
#
#          [[-1.1532, -1.2243, -1.2243,  ..., -0.9399, -0.8688, -0.8119],
#           [-1.2243, -1.3096, -1.2811,  ..., -0.5417, -0.8688, -0.8261],
#           [-1.2811, -1.3238, -1.2811,  ...,  0.0982, -0.1009, -0.8403],
#           ...,
#           [-1.0110, -1.0110, -0.9541,  ..., -0.7550, -0.6555, -0.2146],
#           [-1.0252, -1.0252, -1.0252,  ..., -0.6697, -0.5417, -0.3711],
#           [-0.9399, -0.9967, -0.9114,  ..., -0.5275, -0.4848, -0.2431]]]])

# %%
# Tokenize and encode all plant names (text features) once
with torch.no_grad():
    # Tokenizer accepts list of strings
    text_tokens = tokenizer(plant_names)
    text_tokens = text_tokens.to(device) if hasattr(text_tokens, 'to') else text_tokens
    text_features = model.encode_text(text_tokens)
    text_features = text_features / text_features.norm(dim=-1, keepdim=True)

# Improved Wikipedia fetching: session with retries, batch MediaWiki queries, and local cache
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
import os
import json
from urllib.parse import quote_plus

WIKI_REST_BASE = 'https://en.wikipedia.org/api/rest_v1/page/summary/'
WIKI_API_BASE = 'https://en.wikipedia.org/w/api.php'
HEADERS = {'User-Agent': 'BioCLIP-Eval/1.0 (Educational Project)', 'Accept': 'application/json'}

# Prepare a requests session with retries and backoff
session = requests.Session()
retry_strategy = Retry(
    total=5,
    backoff_factor=0.8,
    status_forcelist=[429, 500, 502, 503, 504],
    allowed_methods=frozenset(["HEAD", "GET", "OPTIONS"])
)
adapter = HTTPAdapter(max_retries=retry_strategy)
session.mount("https://", adapter)
session.mount("http://", adapter)
session.headers.update(HEADERS)

# Local cache for wiki metadata and downloaded thumbnails
cache_path = 'data/wiki_cache.json'
img_cache_dir = 'data/wiki_images'
os.makedirs(img_cache_dir, exist_ok=True)

if os.path.exists(cache_path):
    try:
        with open(cache_path, 'r', encoding='utf-8') as fh:
            wiki_cache = json.load(fh)
    except Exception:
        wiki_cache = {}
else:
    wiki_cache = {}


def save_cache():
    try:
        with open(cache_path, 'w', encoding='utf-8') as fh:
            json.dump(wiki_cache, fh, ensure_ascii=False, indent=2)
    except Exception:
        pass


def slugify_name(name: str) -> str:
    return ''.join(c if c.isalnum() or c in (' ', '-', '_') else '_' for c in name).replace(' ', '_')[:200]


def batch_query_pageimages(names: list, batch_size: int = 50) -> Dict[str, Dict]:
    """Query MediaWiki action=query in batches to get thumbnails for many titles at once.

    Returns a mapping from requested-name -> dict(title, thumbnail, url) for those that had thumbnails.
    """
    mapping = {}
    for i in range(0, len(names), batch_size):
        batch = names[i:i+batch_size]
        titles = '|'.join(batch)
        params = {
            'action': 'query',
            'titles': titles,
            'prop': 'pageimages',
            'pithumbsize': 1000,
            'redirects': 1,
            'format': 'json'
        }
        try:
            resp = session.get(WIKI_API_BASE, params=params, timeout=15)
            if resp.status_code != 200:
                time.sleep(0.1)
                continue
            data = resp.json()
            query = data.get('query', {})
            pages = query.get('pages', {})
            # Build normalized/redirect maps
            norm_map = {n['from']: n['to'] for n in query.get('normalized', [])} if query.get('normalized') else {}
            redir_map = {r['from']: r['to'] for r in query.get('redirects', [])} if query.get('redirects') else {}

            # title -> page mapping
            title_to_page = {page.get('title', ''): page for page in pages.values()}

            for requested in batch:
                mapped = requested
                if requested in norm_map:
                    mapped = norm_map[requested]
                if requested in redir_map:
                    mapped = redir_map[requested]

                page = title_to_page.get(mapped)
                if page:
                    thumb = page.get('thumbnail', {}).get('source', '')
                    if thumb:
                        mapping[requested] = {
                            'title': page.get('title', ''),
                            'thumbnail': thumb,
                            'url': f"https://en.wikipedia.org/?curid={page.get('pageid')}"
                        }
        except Exception:
            # on any error, wait and continue
            time.sleep(0.2)
            continue
        # brief pause between batches
        time.sleep(0.1)
    return mapping


def get_wikipedia_summary_with_thumbnail(scientific_name: str, timeout: int = 10) -> Optional[Dict]:
    """Fallback single-name fetch using REST summary endpoint (used only when batch lookup didn't find a thumbnail).
    Returns dict with title, extract, url, thumbnail or None.
    """
    try:
        encoded = requests.utils.quote(scientific_name)
        resp = session.get(f'{WIKI_REST_BASE}{encoded}', timeout=timeout)
        if resp.status_code == 200:
            data = resp.json()
            thumbnail = data.get('thumbnail', {}).get('source', '') if isinstance(data.get('thumbnail'), dict) else ''
            return {
                'title': data.get('title', ''),
                'extract': data.get('extract', ''),
                'url': data.get('content_urls', {}).get('desktop', {}).get('page', ''),
                'thumbnail': thumbnail
            }
        else:
            return None
    except Exception:
        return None


def download_image_bytes(url: str, timeout: int = 10, attempts: int = 3) -> Optional[bytes]:
    """Download image bytes with retries using the session. Skips SVG/XML content types.
    """
    for attempt in range(attempts):
        try:
            r = session.get(url, timeout=timeout, stream=True)
            if r.status_code == 200:
                content_type = r.headers.get('Content-Type', '').lower()
                if 'svg' in content_type or 'xml' in content_type:
                    return None
                data = r.content
                if data:
                    return data
            else:
                # pause and retry
                time.sleep(0.5 * (attempt + 1))
        except Exception:
            time.sleep(0.5 * (attempt + 1))
            continue
    return None

# %% [markdown]
# ## Test Plant Classifier Class

# %%
# Evaluate across all plant names using cached thumbnails and batch MediaWiki lookup
results = []
start = time.time()

# 1) Use batch MediaWiki query to get thumbnails for many species at once
print('Running batch MediaWiki pageimages lookup...')
batch_map = batch_query_pageimages(plant_names, batch_size=50)
print(f'Batch lookup returned thumbnails for {len(batch_map)} names')

# Helper to get genus from a scientific name
def genus_of(name: str) -> str:
    parts = str(name).split()
    return parts[0] if parts else ''

# Track counters for quick incremental stats (optional)
species_top1 = 0
species_top3 = 0
species_top5 = 0

genus_top1 = 0
genus_top3 = 0
genus_top5 = 0

for i, pname in enumerate(plant_names):
    print(f'[{i+1}/{len(plant_names)}] {pname}', end='')

    # If cached and already has thumbnail stored, reuse
    cache_entry = wiki_cache.get(pname)
    if cache_entry and cache_entry.get('thumbnail'):
        thumb = cache_entry['thumbnail']
        fetch_method = cache_entry.get('fetch_method', 'cache')
    else:
        # Try batch_map first
        meta = batch_map.get(pname)
        fetch_method = None
        if meta and meta.get('thumbnail'):
            thumb = meta['thumbnail']
            fetch_method = 'batch'
        else:
            # Try genus (if different)
            genus = pname.split()[0] if pname.split() else pname
            meta_genus = batch_map.get(genus)
            if meta_genus and meta_genus.get('thumbnail'):
                thumb = meta_genus['thumbnail']
                fetch_method = 'batch_genus'
            else:
                # Finally, try REST summary per-name as fallback
                wiki = get_wikipedia_summary_with_thumbnail(pname)
                if wiki and wiki.get('thumbnail'):
                    thumb = wiki['thumbnail']
                    fetch_method = 'rest'
                else:
                    thumb = ''

        # Save to cache placeholder (we'll enrich later if we download image)
        wiki_cache[pname] = {'thumbnail': thumb, 'fetch_method': fetch_method}
        save_cache()

    if not thumb:
        print(' - no wiki image')
        results.append({
            'plant_name': pname,
            'found_image': False,
            'thumbnail': '',
            'top_1': '',
            'top_1_conf': 0.0,
            'top_5': [],
            'fetch_method': fetch_method,
            'top1_species_match': False,
            'top3_species_match': False,
            'top5_species_match': False,
            'top1_genus_match': False,
            'top3_genus_match': False,
            'top5_genus_match': False,
        })
        # polite sleep
        time.sleep(0.12)
        continue

    # If we've already downloaded this thumbnail image locally, reuse it
    slug = slugify_name(pname)
    img_path = os.path.join(img_cache_dir, f"{slug}.jpg")
    if os.path.exists(img_path):
        with open(img_path, 'rb') as f:
            img_bytes = f.read()
    else:
        img_bytes = download_image_bytes(thumb)
        if img_bytes:
            try:
                with open(img_path, 'wb') as f:
                    f.write(img_bytes)
            except Exception:
                pass

    if not img_bytes:
        print(' - failed download')
        # update cache to mark failure and continue
        wiki_cache[pname] = {'thumbnail': thumb, 'fetch_method': fetch_method, 'downloaded': False}
        save_cache()
        results.append({
            'plant_name': pname,
            'found_image': False,
            'thumbnail': thumb,
            'top_1': '',
            'top_1_conf': 0.0,
            'top_5': [],
            'fetch_method': fetch_method,
            'top1_species_match': False,
            'top3_species_match': False,
            'top5_species_match': False,
            'top1_genus_match': False,
            'top3_genus_match': False,
            'top5_genus_match': False,
        })
        time.sleep(0.12)
        continue

    # Preprocess and classify
    try:
        img = Image.open(BytesIO(img_bytes)).convert('RGB')
        image_tensor = preprocess_val(img).unsqueeze(0).to(device)
    except Exception:
        print(' - image open error')
        wiki_cache[pname] = {'thumbnail': thumb, 'fetch_method': fetch_method, 'downloaded': False}
        save_cache()
        results.append({
            'plant_name': pname,
            'found_image': False,
            'thumbnail': thumb,
            'top_1': '',
            'top_1_conf': 0.0,
            'top_5': [],
            'fetch_method': fetch_method,
            'top1_species_match': False,
            'top3_species_match': False,
            'top5_species_match': False,
            'top1_genus_match': False,
            'top3_genus_match': False,
            'top5_genus_match': False,
        })
        time.sleep(0.12)
        continue

    with torch.no_grad():
        image_features = model.encode_image(image_tensor)
        image_features = image_features / image_features.norm(dim=-1, keepdim=True)
        logits = 100.0 * (image_features @ text_features.T)
        probs = logits.softmax(dim=-1).cpu().numpy()[0]

    top_idxs = probs.argsort()[::-1][:5]
    top5 = [(plant_names[idx], float(probs[idx])) for idx in top_idxs]
    top_names = [t[0] for t in top5]
    top1_name, top1_conf = top5[0][0], top5[0][1]

    # Species-level matches
    top1_species_match = (top1_name == pname)
    top3_species_match = any((name == pname) for name in top_names[:3])
    top5_species_match = any((name == pname) for name in top_names[:5])

    # Genus-level matches: compare genus (first token)
    true_genus = genus_of(pname)
    pred_genera = [genus_of(n) for n in top_names]
    top1_genus_match = (pred_genera[0] == true_genus)
    top3_genus_match = any((g == true_genus) for g in pred_genera[:3])
    top5_genus_match = any((g == true_genus) for g in pred_genera[:5])

    # Increment counters
    species_top1 += int(top1_species_match)
    species_top3 += int(top3_species_match)
    species_top5 += int(top5_species_match)

    genus_top1 += int(top1_genus_match)
    genus_top3 += int(top3_genus_match)
    genus_top5 += int(top5_genus_match)

    correct = top1_species_match
    print(f' - image OK - top1={top1_name} ({top1_conf*100:.2f}%)' + ( ' ✅' if correct else '' ))

    # update cache
    try:
        wiki_cache[pname].update({'downloaded': True, 'local_path': img_path, 'title': wiki_cache.get(pname, {}).get('title', '')})
        save_cache()
    except Exception:
        pass

    results.append({
        'plant_name': pname,
        'found_image': True,
        'thumbnail': thumb,
        'top_1': top1_name,
        'top_1_conf': float(top1_conf),
        'top_5': top5,
        'fetch_method': fetch_method,
        'top1_species_match': top1_species_match,
        'top3_species_match': top3_species_match,
        'top5_species_match': top5_species_match,
        'top1_genus_match': top1_genus_match,
        'top3_genus_match': top3_genus_match,
        'top5_genus_match': top5_genus_match,
    })

    # polite sleep between processing items
    time.sleep(0.12)

# Save results to CSV and show summary
out_df = pd.DataFrame(results)

# Compute overall metrics (consider only rows where found_image==True)
# Make an explicit copy to avoid SettingWithCopyWarning when assigning new columns
with_images_df = out_df[out_df['found_image'] == True].copy()
num_with_images = len(with_images_df)
num_total = len(out_df)

summary = {
    'total_species_evaluated': num_total,
    'total_with_images': num_with_images,
}

if num_with_images > 0:
    summary.update({
        'species_top1_count': int(with_images_df['top1_species_match'].sum()),
        'species_top3_count': int(with_images_df['top3_species_match'].sum()),
        'species_top5_count': int(with_images_df['top5_species_match'].sum()),
        'species_top1_acc': float(with_images_df['top1_species_match'].sum() / num_with_images),
        'species_top3_acc': float(with_images_df['top3_species_match'].sum() / num_with_images),
        'species_top5_acc': float(with_images_df['top5_species_match'].sum() / num_with_images),
        'genus_top1_count': int(with_images_df['top1_genus_match'].sum()),
        'genus_top3_count': int(with_images_df['top3_genus_match'].sum()),
        'genus_top5_count': int(with_images_df['top5_genus_match'].sum()),
        'genus_top1_acc': float(with_images_df['top1_genus_match'].sum() / num_with_images),
        'genus_top3_acc': float(with_images_df['top3_genus_match'].sum() / num_with_images),
        'genus_top5_acc': float(with_images_df['top5_genus_match'].sum() / num_with_images),
    })

# --- New: Accuracy by confidence bins (top-1 predicted confidence)
# Define bins (upper-inclusive for the top interval)
bin_edges = [0.0, 0.6, 0.7, 0.8, 0.9, 1.0]
bin_labels = ['<0.6', '0.6-0.7', '0.7-0.8', '0.8-0.9', '>=0.9']

# Ensure top_1_conf is numeric and within [0,1] (use .loc to assign explicitly)
with_images_df.loc[:, 'top_1_conf'] = with_images_df['top_1_conf'].fillna(0.0).astype(float).clip(0.0, 1.0)

# Categorize into bins (assign via .loc to avoid chained-assignment warnings)
with_images_df.loc[:, 'conf_bin'] = pd.cut(with_images_df['top_1_conf'], bins=bin_edges, labels=bin_labels, include_lowest=True, right=False)

# Compute metrics per bin
conf_summary = []
for label in bin_labels:
    bin_df = with_images_df[with_images_df['conf_bin'] == label]
    cnt = len(bin_df)
    if cnt == 0:
        conf_summary.append({
            'conf_bin': label,
            'count': 0,
            'species_top1_acc': None,
            'genus_top1_acc': None
        })
        continue
    species_correct = int(bin_df['top1_species_match'].sum())
    genus_correct = int(bin_df['top1_genus_match'].sum())
    conf_summary.append({
        'conf_bin': label,
        'count': cnt,
        'species_top1_acc': float(species_correct / cnt),
        'genus_top1_acc': float(genus_correct / cnt)
    })

# Add conf_summary to summary dict and also print table
summary['confidence_bins'] = conf_summary

out_path = 'data/bioclip_wikipedia_eval.csv'
out_df.to_csv(out_path, index=False)

elapsed = time.time() - start
print(f"\nDone. Results saved to {out_path}. Elapsed: {elapsed:.1f}s")

# Print summary nicely
print('\nSummary:')
for k, v in summary.items():
    if k == 'confidence_bins':
        print('  confidence_bins:')
        for b in v:
            if b['count'] == 0:
                print(f"    {b['conf_bin']}: count=0")
            else:
                print(f"    {b['conf_bin']}: count={b['count']}, species_top1_acc={b['species_top1_acc']:.3f}, genus_top1_acc={b['genus_top1_acc']:.3f}")
    elif isinstance(v, float):
        print(f'  {k}: {v:.3f}')
    else:
        print(f'  {k}: {v}')
# Out:
# Running batch MediaWiki pageimages lookup...
# Batch lookup returned thumbnails for 264 names
# [1/349] Adiantum peruvianum - image OK - top1=Adiantum peruvianum (99.98%) ✅
# Batch lookup returned thumbnails for 264 names
# [83/349] Guzmania - image OK - top1=Vriesea (41.28%)
# [83/349] Guzmania - image OK - top1=Vriesea (41.28%)
# [84/349] Guzmania lingulata - image OK - top1=Vriesea imperialis green (68.10%)
# [84/349] Guzmania lingulata - image OK - top1=Vriesea imperialis green (68.10%)
# [85/349] Hedychium - image OK - top1=Hedychium (99.70%) ✅
# [85/349] Hedychium - image OK - top1=Hedychium (99.70%) ✅
# [86/349] Hibiscus clayi - image OK - top1=Hibiscus clayi (93.42%) ✅
# [86/349] Hibiscus clayi - image OK - top1=Hibiscus clayi (93.42%) ✅
# [87/349] Hippeastrum - image OK - top1=Hippeastrum (99.96%) ✅
# [87/349] Hippeastrum - image OK - top1=Hippeastrum (99.96%) ✅
# [88/349] Hohenbergia catingae - image OK - top1=Hohenbergia catingae (39.72%) ✅
# [88/349] Hohenbergia catingae - image OK - top1=Hohenbergia catingae (39.72%) ✅
# [89/349] Hohenbergia lemei - no wiki image
# [90/349] Hohenbergia rosea - no wiki image
# [89/349] Hohenbergia lemei - no wiki image
# [90/349] Hohenbergia rosea - no wiki image
# [91/349] Homalocladium platycladum - image OK - top1=Euphorbia tirucalli (27.12%)
# [91/349] Homalocladium platycladum - image OK - top1=Euphorbia tirucalli (27.12%)
# [92/349] Hoya carnosa - image OK - top1=Hoya carnosa (86.51%) ✅
# [92/349] Hoya carnosa - image OK - top1=Hoya carnosa (86.51%) ✅
# [93/349] Pombalia communis - no wiki image
# [94/349] Pombalia prunifolia - no wiki image
# [93/349] Pombalia communis - no wiki image
# [94/349] Pombalia prunifolia - no wiki image
# [95/349] Selenicereus undatus - image OK - top1=Gasteria excelsa (29.66%)
# [95/349] Selenicereus undatus - image OK - top1=Gasteria excelsa (29.66%)
# [96/349] Hymenocallis caribaea - image OK - top1=Hymenocallis caribaea (78.74%) ✅
# [96/349] Hymenocallis caribaea - image OK - top1=Hymenocallis caribaea (78.74%) ✅
# [97/349] Kaempferia pulchra - image OK - top1=Kaempferia pulchra (95.40%) ✅
# [97/349] Kaempferia pulchra - image OK - top1=Kaempferia pulchra (95.40%) ✅
# [98/349] Medinilla magnifica - image OK - top1=Medinilla magnifica (91.18%) ✅
# [98/349] Medinilla magnifica - image OK - top1=Medinilla magnifica (91.18%) ✅
# [99/349] Microsorum musifolium - no wiki image
# [100/349] Microsorum punctatum[99/349] Microsorum musifolium - no wiki image
# [100/349] Microsorum punctatum - image OK - top1=Microsorum punctatum (62.60%) ✅
# [101/349] Monstera deliciosa - image OK - top1=Microsorum punctatum (62.60%) ✅
# [101/349] Monstera deliciosa - image OK - top1=Monstera deliciosa (83.23%) ✅
# [102/349] Monstera obliqua - image OK - top1=Monstera deliciosa (83.23%) ✅
# [102/349] Monstera obliqua - image OK - top1=Anthurium podophyllum (74.09%)
# [103/349] Murraya paniculata - image OK - top1=Anthurium podophyllum (74.09%)
# [103/349] Murraya paniculata - image OK - top1=Murraya paniculata (98.13%) ✅
# [104/349] Nematanthus - image OK - top1=Murraya paniculata (98.13%) ✅
# [104/349] Nematanthus - image OK - top1=Boophane disticha (55.84%)
# [105/349] Neoregelia - image OK - top1=Boophane disticha (55.84%)
# [105/349] Neoregelia - image OK - top1=Vriesea (59.49%)
# [106/349] Nerium oleander - image OK - top1=Vriesea (59.49%)
# [106/349] Nerium oleander - image OK - top1=Nerium oleander (98.97%) ✅
# [107/349] Oncidium sphacelatum - image OK - top1=Nerium oleander (98.97%) ✅
# [107/349] Oncidium sphacelatum - image OK - top1=Oncidium sphacelatum (74.28%) ✅
# [108/349] Pandanus tectorius - image OK - top1=Oncidium sphacelatum (74.28%) ✅
# [108/349] Pandanus tectorius - image OK - top1=Pandanus tectorius (97.99%) ✅
# [109/349] Pavonia - no wiki image
#  - image OK - top1=Pandanus tectorius (97.99%) ✅
# [109/349] Pavonia - no wiki image
# [110/349] Peperomia prostrata - image OK - top1=Peperomia prostrata (71.73%) ✅
# [110/349] Peperomia prostrata - image OK - top1=Peperomia prostrata (71.73%) ✅
# [111/349] Peperomia rotundifolia - image OK - top1=Peperomia rotundifolia (97.15%) ✅
# [111/349] Peperomia rotundifolia - image OK - top1=Peperomia rotundifolia (97.15%) ✅
# [112/349] Philodendron - image OK - top1=Philodendron (95.12%) ✅
# [112/349] Philodendron - image OK - top1=Philodendron (95.12%) ✅
# [113/349] Philodendron billietiae - image OK - top1=Philodendron billietiae (89.33%) ✅
# [113/349] Philodendron billietiae - image OK - top1=Philodendron billietiae (89.33%) ✅
# [114/349] Philodendron burle-marxii - image OK - top1=Monstera obliqua (48.81%)
# [114/349] Philodendron burle-marxii - image OK - top1=Monstera obliqua (48.81%)
# [115/349] Philodendron copense - image OK - top1=Philodendron (95.12%)
# [115/349] Philodendron copense - image OK - top1=Philodendron (95.12%)
# [116/349] Philodendron gloriosum - image OK - top1=Philodendron gloriosum (53.78%) ✅
# [116/349] Philodendron gloriosum - image OK - top1=Philodendron gloriosum (53.78%) ✅
# [117/349] Philodendron hastatum - image OK - top1=Philodendron hastatum (79.24%) ✅
# [117/349] Philodendron hastatum - image OK - top1=Philodendron hastatum (79.24%) ✅
# [118/349] Philodendron martianum - image OK - top1=Philodendron martianum (32.86%) ✅
# [118/349] Philodendron martianum - image OK - top1=Philodendron martianum (32.86%) ✅
# [119/349] Philodendron melanochrysum - image OK - top1=Philodendron (25.96%)
# [119/349] Philodendron melanochrysum - image OK - top1=Philodendron (25.96%)
# [120/349] Philodendron pastazanum - image OK - top1=Philodendron pastazanum (97.05%) ✅
# [120/349] Philodendron pastazanum - image OK - top1=Philodendron pastazanum (97.05%) ✅
# [121/349] Philodendron plowmanii - image OK - top1=Philodendron (95.12%)
# [121/349] Philodendron plowmanii - image OK - top1=Philodendron (95.12%)
# [122/349] Philodendron warscewiczii - image OK - top1=Philodendron (95.12%)
# [122/349] Philodendron warscewiczii - image OK - top1=Philodendron (95.12%)
# [123/349] Pilea peperomioides - image OK - top1=Vanilla planifolia (42.67%)
# [123/349] Pilea peperomioides - image OK - top1=Vanilla planifolia (42.67%)
# [124/349] Piper nigrum - image OK - top1=Piper nigrum (97.95%) ✅
# [124/349] Piper nigrum - image OK - top1=Piper nigrum (97.95%) ✅
# [125/349] Piper unguiculatum - no wiki image
# [126/349] Platycerium alcicorne[125/349] Piper unguiculatum - no wiki image
# [126/349] Platycerium alcicorne - image OK - top1=Platycerium alcicorne (99.70%) ✅
# [127/349] Plinia cauliflora - image OK - top1=Platycerium alcicorne (99.70%) ✅
# [127/349] Plinia cauliflora - image OK - top1=Gasteria (18.74%)
# [128/349] Plumeria rubra - image OK - top1=Gasteria (18.74%)
# [128/349] Plumeria rubra - image OK - top1=Plumeria rubra (96.26%) ✅
# [129/349] Polyscias guilfoylei - image OK - top1=Plumeria rubra (96.26%) ✅
# [129/349] Polyscias guilfoylei - image OK - top1=Adiantum raddianum (36.58%)
# [130/349] Portea - image OK - top1=Adiantum raddianum (36.58%)
# [130/349] Portea - image OK - top1=Aechmea gamosepala (58.89%)
# [131/349] Pseuderanthemum laxiflorum - image OK - top1=Aechmea gamosepala (58.89%)
# [131/349] Pseuderanthemum laxiflorum - image OK - top1=Pseuderanthemum laxiflorum (97.10%) ✅
# [132/349] Psilotum nudum - image OK - top1=Pseuderanthemum laxiflorum (97.10%) ✅
# [132/349] Psilotum nudum - image OK - top1=Psilotum nudum (99.81%) ✅
# [133/349] Quesnelia marmorata - image OK - top1=Psilotum nudum (99.81%) ✅
# [133/349] Quesnelia marmorata - image OK - top1=Billbergia (57.58%)
# [134/349] Rhaphidophora tetrasperma - image OK - top1=Billbergia (57.58%)
# [134/349] Rhaphidophora tetrasperma - image OK - top1=Monstera deliciosa (50.89%)
# [135/349] Rhipsalis pilocarpa - image OK - top1=Monstera deliciosa (50.89%)
# [135/349] Rhipsalis pilocarpa - image OK - top1=Rhipsalis pilocarpa (93.91%) ✅
# [136/349] Ruellia prostrata - image OK - top1=Rhipsalis pilocarpa (93.91%) ✅
# [136/349] Ruellia prostrata - image OK - top1=Ruellia prostrata (68.27%) ✅
# [137/349] Ruellia simplex - image OK - top1=Ruellia prostrata (68.27%) ✅
# [137/349] Ruellia simplex - image OK - top1=Ruellia simplex (53.94%) ✅
# [138/349] Saccharum officinarum - image OK - top1=Ruellia simplex (53.94%) ✅
# [138/349] Saccharum officinarum - image OK - top1=Saccharum officinarum (41.23%) ✅
# [139/349] Sauromatum venosum - image OK - top1=Saccharum officinarum (41.23%) ✅
# [139/349] Sauromatum venosum - image OK - top1=Monstera deliciosa (61.69%)
# [140/349] Selenicereus anthonyanus - image OK - top1=Monstera deliciosa (61.69%)
# [140/349] Selenicereus anthonyanus - image OK - top1=Cleistocactus (61.90%)
# [141/349] Tapeinochilos ananassae - image OK - top1=Cleistocactus (61.90%)
# [141/349] Tapeinochilos ananassae - image OK - top1=Aechmea (72.90%)
# [142/349] Wallisia cyanea - image OK - top1=Aechmea (72.90%)
# [142/349] Wallisia cyanea - image OK - top1=Guzmania (52.20%)
# [143/349] Tillandsia xerographica - image OK - top1=Guzmania (52.20%)
# [143/349] Tillandsia xerographica - image OK - top1=Vriesea (50.32%)
# [144/349] Typhonodorum lindleyanum - image OK - top1=Vriesea (50.32%)
# [144/349] Typhonodorum lindleyanum - image OK - top1=Amorphophallus titanum (67.23%)
# [145/349] Vanilla planifolia - image OK - top1=Amorphophallus titanum (67.23%)
# [145/349] Vanilla planifolia - image OK - top1=Aspidistra elatior (72.38%)
# [146/349] Vriesea - image OK - top1=Aspidistra elatior (72.38%)
# [146/349] Vriesea - image OK - top1=Vriesea (69.93%) ✅
# [147/349] Vriesea imperialis green - image OK - top1=Vriesea (69.93%) ✅
# [147/349] Vriesea imperialis green - image OK - top1=Vriesea (69.93%)
# [148/349] Vriesea simplex - image OK - top1=Vriesea (69.93%)
# [148/349] Vriesea simplex - image OK - top1=Vriesea (69.93%)
# [149/349] Vriesea splendens - image OK - top1=Vriesea (69.93%)
# [149/349] Vriesea splendens - image OK - top1=Vriesea (58.60%)
# [150/349] Zamia furfuraceae - no wiki image
#  - image OK - top1=Vriesea (58.60%)
# [150/349] Zamia furfuraceae - no wiki image
# [151/349] Zamioculcas zamiifolia - image OK - top1=Murraya paniculata (65.29%)
# [151/349] Zamioculcas zamiifolia - image OK - top1=Murraya paniculata (65.29%)
# [152/349] Zapoteca portoricensis - no wiki image
# [153/349] Zingiber officianale - no wiki image
# [152/349] Zapoteca portoricensis - no wiki image
# [153/349] Zingiber officianale - no wiki image
# [154/349] Zingiber zerumbet - image OK - top1=Zingiber zerumbet (65.31%) ✅
# [154/349] Zingiber zerumbet - image OK - top1=Zingiber zerumbet (65.31%) ✅
# [155/349] Agave angustifolia - image OK - top1=Agave angustifolia (54.93%) ✅
# [155/349] Agave angustifolia - image OK - top1=Agave angustifolia (54.93%) ✅
# [156/349] Agave schottii - image OK - top1=Agave lechuguilla (91.41%)
# [156/349] Agave schottii - image OK - top1=Agave lechuguilla (91.41%)
# [157/349] Agave stricta - image OK - top1=Yucca elata (87.19%)
# [157/349] Agave stricta - image OK - top1=Yucca elata (87.19%)
# [158/349] Aloe - image OK - top1=Aloe arborescens (58.53%)
# [158/349] Aloe - image OK - top1=Aloe arborescens (58.53%)
# [159/349] Drimiopsis maculata - image OK - top1=Aechmea gamosepala (42.76%)
# [159/349] Drimiopsis maculata - image OK - top1=Aechmea gamosepala (42.76%)
# [160/349] Euphorbia abyssinica - image OK - top1=Euphorbia abyssinica (63.44%) ✅
# [160/349] Euphorbia abyssinica - image OK - top1=Euphorbia abyssinica (63.44%) ✅
# [161/349] Euphorbia - image OK - top1=Euphorbia (99.99%) ✅
# [161/349] Euphorbia - image OK - top1=Euphorbia (99.99%) ✅
# [162/349] Ferocactus emoryi - image OK - top1=Ferocactus (58.48%)
# [162/349] Ferocactus emoryi - image OK - top1=Ferocactus (58.48%)
# [163/349] Ferocactus - image OK - top1=Ferocactus hystrix (96.13%)
# [163/349] Ferocactus - image OK - top1=Ferocactus hystrix (96.13%)
# [164/349] Fouquieria formosa - image OK - top1=Fouquieria formosa (87.49%) ✅
# [164/349] Fouquieria formosa - image OK - top1=Fouquieria formosa (87.49%) ✅
# [165/349] Gasteraloe - image OK - top1=Gasteria species (68.17%)
# [165/349] Gasteraloe - image OK - top1=Gasteria species (68.17%)
# [166/349] Gasteria hybrid - image OK - top1=Gasteria species (90.31%)
# [166/349] Gasteria hybrid - image OK - top1=Gasteria species (90.31%)
# [167/349] Gasteria - image OK - top1=Gasteria species (90.31%)
# [167/349] Gasteria - image OK - top1=Gasteria species (90.31%)
# [168/349] Gasteria species - image OK - top1=Gasteria species (90.31%) ✅
# [168/349] Gasteria species - image OK - top1=Gasteria species (90.31%) ✅
# [169/349] Gasterworthia - no wiki image
# [170/349] Graptopetalum[169/349] Gasterworthia - no wiki image
# [170/349] Graptopetalum - image OK - top1=Graptopetalum (63.92%) ✅
# [171/349] Graptoveria #2(?) - no wiki image
#  - image OK - top1=Graptopetalum (63.92%) ✅
# [171/349] Graptoveria #2(?) - no wiki image
# [172/349] Graptoveria #3(?) - no wiki image
# [173/349] Gymnocalycium possibly saglione[172/349] Graptoveria #3(?) - no wiki image
# [173/349] Gymnocalycium possibly saglione - image OK - top1=Gymnocalycium (29.21%)
# [174/349] Gymnocalycium - image OK - top1=Gymnocalycium (29.21%)
# [174/349] Gymnocalycium - image OK - top1=Gymnocalycium (29.21%) ✅
# [175/349] Haworthia - image OK - top1=Gymnocalycium (29.21%) ✅
# [175/349] Haworthia - image OK - top1=Haworthia (65.92%) ✅
# [176/349] Haworthiopsis attenuata - image OK - top1=Haworthia (65.92%) ✅
# [176/349] Haworthiopsis attenuata - image OK - top1=Haworthiopsis attenuata (93.80%) ✅
# [177/349] Hectia argentea - no wiki image
#  - image OK - top1=Haworthiopsis attenuata (93.80%) ✅
# [177/349] Hectia argentea - no wiki image
# [178/349] Hectia - no wiki image
# [179/349] Juttadinteria suavissima - no wiki image
# [178/349] Hectia - no wiki image
# [179/349] Juttadinteria suavissima - no wiki image
# [180/349] Mammillaria - image OK - top1=Mammillaria (99.09%) ✅
# [180/349] Mammillaria - image OK - top1=Mammillaria (99.09%) ✅
# [181/349] Opuntia - image OK - top1=Opuntia (82.10%) ✅
# [181/349] Opuntia - image OK - top1=Opuntia (82.10%) ✅
# [182/349] Raphianacme flanaganii - no wiki image
# [183/349] Sedum pachyphyllum - no wiki image
# [182/349] Raphianacme flanaganii - no wiki image
# [183/349] Sedum pachyphyllum - no wiki image
# [184/349] Senecio crassisimus - no wiki image
# [185/349] Unknown - no wiki image
# [184/349] Senecio crassisimus - no wiki image
# [185/349] Unknown - no wiki image
# [186/349] Adenium boehmianum - image OK - top1=Nerium oleander (85.98%)
# [186/349] Adenium boehmianum - image OK - top1=Nerium oleander (85.98%)
# [187/349] Aloe cameronii - image OK - top1=Aloe arborescens (45.18%)
# [187/349] Aloe cameronii - image OK - top1=Aloe arborescens (45.18%)
# [188/349] Aloe harlana - image OK - top1=Aloe maculata (75.61%)
# [188/349] Aloe harlana - image OK - top1=Aloe maculata (75.61%)
# [189/349] Aloe jacksonii - image OK - top1=Aloe arborescens (58.53%)
# [189/349] Aloe jacksonii - image OK - top1=Aloe arborescens (58.53%)
# [190/349] Aloe jucunda - image OK - top1=Aloe jucunda (94.22%) ✅
# [190/349] Aloe jucunda - image OK - top1=Aloe jucunda (94.22%) ✅
# [191/349] Aloe maculata - image OK - top1=Aloe jucunda (41.27%)
# [191/349] Aloe maculata - image OK - top1=Aloe jucunda (41.27%)
# [192/349] Aloe munchii - image OK - top1=Aloe arborescens (58.53%)
# [192/349] Aloe munchii - image OK - top1=Aloe arborescens (58.53%)
# [193/349] Aloe rivae - image OK - top1=Aloe arborescens (58.53%)
# [193/349] Aloe rivae - image OK - top1=Aloe arborescens (58.53%)
# [194/349] Aloe rivierei - image OK - top1=Aloe arborescens (58.53%)
# [194/349] Aloe rivierei - image OK - top1=Aloe arborescens (58.53%)
# [195/349] Dracaena serpenta - no wiki image
# [196/349] Dracaena - no wiki image
# [195/349] Dracaena serpenta - no wiki image
# [196/349] Dracaena - no wiki image
# [197/349] Euphorbia tirucalli - image OK - top1=Euphorbia tirucalli (99.87%) ✅
# [197/349] Euphorbia tirucalli - image OK - top1=Euphorbia tirucalli (99.87%) ✅
# [198/349] Gasteria obliqua - image OK - top1=Leuchtenbergia principis (39.35%)
# [198/349] Gasteria obliqua - image OK - top1=Leuchtenbergia principis (39.35%)
# [199/349] Tephrocactus articulatus - image OK - top1=Euphorbia (43.97%)
# [199/349] Tephrocactus articulatus - image OK - top1=Euphorbia (43.97%)
# [200/349] STETSONIA CORYNE - no wiki image
# [201/349] Carnegiea gigantea[200/349] STETSONIA CORYNE - no wiki image
# [201/349] Carnegiea gigantea - image OK - top1=Carnegiea gigantea (99.99%) ✅
# [202/349] Yucca elata - image OK - top1=Carnegiea gigantea (99.99%) ✅
# [202/349] Yucca elata - image OK - top1=Yucca elata (99.96%) ✅
# [203/349] Brachychiton rupestris - image OK - top1=Yucca elata (99.96%) ✅
# [203/349] Brachychiton rupestris - image OK - top1=Brachychiton rupestris (99.43%) ✅
# [204/349] Brachychiton - image OK - top1=Brachychiton rupestris (99.43%) ✅
# [204/349] Brachychiton - image OK - top1=Brachychiton (99.31%) ✅
# [205/349] Hohenbergia magnispina - no wiki image
#  - image OK - top1=Brachychiton (99.31%) ✅
# [205/349] Hohenbergia magnispina - no wiki image
# [206/349] Aloe deltoideodonta - image OK - top1=Aloe jucunda (35.53%)
# [206/349] Aloe deltoideodonta - image OK - top1=Aloe jucunda (35.53%)
# [207/349] Calibanus hookeri - image OK - top1=Euphorbia antisyphilitica (83.86%)
# [207/349] Calibanus hookeri - image OK - top1=Euphorbia antisyphilitica (83.86%)
# [208/349] Cephalocereus senilis - image OK - top1=Cephalocereus senilis (60.68%) ✅
# [208/349] Cephalocereus senilis - image OK - top1=Cephalocereus senilis (60.68%) ✅
# [209/349] Copiapoa gigantea - image OK - top1=Carnegiea gigantea (67.95%)
# [209/349] Copiapoa gigantea - image OK - top1=Carnegiea gigantea (67.95%)
# [210/349] Dracaena ballyi - image OK - top1=Kalanchoe beauverdii (79.15%)
# [253/349] Agave polianthiflora - image OK - top1=Agave lechuguilla (47.75%)
# [253/349] Agave polianthiflora - image OK - top1=Agave lechuguilla (47.75%)
# [254/349] Agave potatorum - image OK - top1=Agave (70.77%)
# [254/349] Agave potatorum - image OK - top1=Agave (70.77%)
# [255/349] Agave tequilana - image OK - top1=Agave americana (78.38%)
# [255/349] Agave tequilana - image OK - top1=Agave americana (78.38%)
# [256/349] Agave titanota - image OK - top1=Agave tequilana (52.86%)
# [256/349] Agave titanota - image OK - top1=Agave tequilana (52.86%)
# [257/349] Agave victoriae-reginae - image OK - top1=Agave victoriae-reginae (99.89%) ✅
# [257/349] Agave victoriae-reginae - image OK - top1=Agave victoriae-reginae (99.89%) ✅
# [258/349] Astrophytum myriostigma - image OK - top1=Lithops hookeri (70.62%)
# [258/349] Astrophytum myriostigma - image OK - top1=Lithops hookeri (70.62%)
# [259/349] Astrophytum ornatum - image OK - top1=Astrophytum ornatum (99.45%) ✅
# [259/349] Astrophytum ornatum - image OK - top1=Astrophytum ornatum (99.45%) ✅
# [260/349] Beaucarnea recurvata - image OK - top1=Beaucarnea recurvata (99.98%) ✅
# [260/349] Beaucarnea recurvata - image OK - top1=Beaucarnea recurvata (99.98%) ✅
# [261/349] Echeveria carnicolor - image OK - top1=PACHYPHYTUM BRACTEOSUM (72.75%)
# [261/349] Echeveria carnicolor - image OK - top1=PACHYPHYTUM BRACTEOSUM (72.75%)
# [262/349] Echinocereus brandegeei - image OK - top1=Cleistocactus (50.82%)
# [262/349] Echinocereus brandegeei - image OK - top1=Cleistocactus (50.82%)
# [263/349] Echinocereus pentalophus - image OK - top1=Echinocereus pentalophus (99.99%) ✅
# [263/349] Echinocereus pentalophus - image OK - top1=Echinocereus pentalophus (99.99%) ✅
# [264/349] Euphorbia lomelii - image OK - top1=Euphorbia antisyphilitica (60.67%)
# [264/349] Euphorbia lomelii - image OK - top1=Euphorbia antisyphilitica (60.67%)
# [265/349] Ferocactus hystrix - image OK - top1=Ferocactus hystrix (96.13%) ✅
# [265/349] Ferocactus hystrix - image OK - top1=Ferocactus hystrix (96.13%) ✅
# [266/349] Ferocactus pilosus - image OK - top1=Ferocactus pilosus (86.19%) ✅
# [266/349] Ferocactus pilosus - image OK - top1=Ferocactus pilosus (86.19%) ✅
# [267/349] Ferocactus rectispinus - image OK - top1=Ferocactus hystrix (96.13%)
# [267/349] Ferocactus rectispinus - image OK - top1=Ferocactus hystrix (96.13%)
# [268/349] Graptopetalum amethystinum - image OK - top1=Graptopetalum (63.92%)
# [268/349] Graptopetalum amethystinum - image OK - top1=Graptopetalum (63.92%)
# [269/349] Graptopetalum paraguayense - image OK - top1=Graptopetalum (56.94%)
# [269/349] Graptopetalum paraguayense - image OK - top1=Graptopetalum (56.94%)
# [270/349] Hamatocactus hamatacanthus - image OK - top1=Ferocactus (58.30%)
# [270/349] Hamatocactus hamatacanthus - image OK - top1=Ferocactus (58.30%)
# [271/349] Leuchtenbergia principis - image OK - top1=Leuchtenbergia principis (88.28%) ✅
# [271/349] Leuchtenbergia principis - image OK - top1=Leuchtenbergia principis (88.28%) ✅
# [272/349] Lophocereus schottii - image OK - top1=Lophocereus schottii (94.84%) ✅
# [272/349] Lophocereus schottii - image OK - top1=Lophocereus schottii (94.84%) ✅
# [273/349] Mammillaria decipiens - image OK - top1=Mammillaria (99.09%)
# [273/349] Mammillaria decipiens - image OK - top1=Mammillaria (99.09%)
# [274/349] Mammillaria geminispina - image OK - top1=Mammillaria geminispina (96.49%) ✅
# [274/349] Mammillaria geminispina - image OK - top1=Mammillaria geminispina (96.49%) ✅
# [275/349] Mammillaria hahniana - image OK - top1=Mammillaria hahniana (99.95%) ✅
# [275/349] Mammillaria hahniana - image OK - top1=Mammillaria hahniana (99.95%) ✅
# [276/349] Mammillaria parkinsonii - image OK - top1=Mammillaria parkinsonii (94.40%) ✅
# [276/349] Mammillaria parkinsonii - image OK - top1=Mammillaria parkinsonii (94.40%) ✅
# [277/349] Mammillaria petterssonii - image OK - top1=Mammillaria petterssonii (57.11%) ✅
# [277/349] Mammillaria petterssonii - image OK - top1=Mammillaria petterssonii (57.11%) ✅
# [278/349] Mammillaria vetula - image OK - top1=Mammillaria vetula (99.38%) ✅
# [278/349] Mammillaria vetula - image OK - top1=Mammillaria vetula (99.38%) ✅
# [279/349] Lophocereus marginatus - image OK - top1=Euphorbia antisyphilitica (43.75%)
# [279/349] Lophocereus marginatus - image OK - top1=Euphorbia antisyphilitica (43.75%)
# [280/349] Opuntia aciculata - image OK - top1=Opuntia phaecantha (86.05%)
# [280/349] Opuntia aciculata - image OK - top1=Opuntia phaecantha (86.05%)
# [281/349] Opuntia robusta - image OK - top1=Opuntia robusta (96.12%) ✅
# [281/349] Opuntia robusta - image OK - top1=Opuntia robusta (96.12%) ✅
# [282/349] Pachycereus - image OK - top1=Cleistocactus (37.92%)
# [282/349] Pachycereus - image OK - top1=Cleistocactus (37.92%)
# [283/349] PACHYPHYTUM BRACTEOSUM - no wiki image
# [284/349] Sedum adolphii[283/349] PACHYPHYTUM BRACTEOSUM - no wiki image
# [284/349] Sedum adolphii - image OK - top1=PACHYPHYTUM BRACTEOSUM (99.42%)
# [285/349] Sedum morganianum - image OK - top1=PACHYPHYTUM BRACTEOSUM (99.42%)
# [285/349] Sedum morganianum - image OK - top1=Hoya carnosa (32.06%)
# [286/349] Cleistocactus hyalacanthus - image OK - top1=Hoya carnosa (32.06%)
# [286/349] Cleistocactus hyalacanthus - image OK - top1=Cleistocactus (98.95%)
# [287/349] Fouquieria splendens - image OK - top1=Cleistocactus (98.95%)
# [287/349] Fouquieria splendens - image OK - top1=Fouquieria splendens (99.99%) ✅
# [288/349] Ariocarpus fissuratus - image OK - top1=Fouquieria splendens (99.99%) ✅
# [288/349] Ariocarpus fissuratus - image OK - top1=Gymnocalycium (53.86%)
# [289/349] ADENIA SPINOSA - no wiki image
#  - image OK - top1=Gymnocalycium (53.86%)
# [289/349] ADENIA SPINOSA - no wiki image
# [290/349] Aloe alooides - image OK - top1=Aloe arborescens (58.53%)
# [290/349] Aloe alooides - image OK - top1=Aloe arborescens (58.53%)
# [291/349] Aloe broomii - image OK - top1=Aloe maculata (50.70%)
# [291/349] Aloe broomii - image OK - top1=Aloe maculata (50.70%)
# [292/349] Aloe ferox - image OK - top1=Aloe ferox (67.57%) ✅
# [292/349] Aloe ferox - image OK - top1=Aloe ferox (67.57%) ✅
# [293/349] Aloe krapohliana - image OK - top1=Aloe arborescens (58.53%)
# [293/349] Aloe krapohliana - image OK - top1=Aloe arborescens (58.53%)
# [294/349] Aloiampelos ciliaris - image OK - top1=Aloiampelos ciliaris (95.10%) ✅
# [294/349] Aloiampelos ciliaris - image OK - top1=Aloiampelos ciliaris (95.10%) ✅
# [295/349] Boophane disticha - no wiki image
# [296/349] Bowiea volubilis[295/349] Boophane disticha - no wiki image
# [296/349] Bowiea volubilis - image OK - top1=Cola acuminata (49.27%)
# [297/349] Crassula arborescens - image OK - top1=Cola acuminata (49.27%)
# [297/349] Crassula arborescens - image OK - top1=Crassula ovata (91.56%)
# [298/349] Crassula ovata - image OK - top1=Crassula ovata (91.56%)
# [298/349] Crassula ovata - image OK - top1=Crassula ovata (99.74%) ✅
# [299/349] Cyphostemma juttae - image OK - top1=Crassula ovata (99.74%) ✅
# [299/349] Cyphostemma juttae - image OK - top1=Astrophytum myriostigma (81.08%)
# [300/349] Euphorbia horrida - image OK - top1=Astrophytum myriostigma (81.08%)
# [300/349] Euphorbia horrida - image OK - top1=Euphorbia abyssinica (64.14%)
# [301/349] Euphorbia obesa - image OK - top1=Euphorbia abyssinica (64.14%)
# [301/349] Euphorbia obesa - image OK - top1=Euphorbia obesa (43.57%) ✅
# [302/349] Gasteria excelsa - image OK - top1=Euphorbia obesa (43.57%) ✅
# [302/349] Gasteria excelsa - image OK - top1=Aloe jucunda (83.02%)
# [303/349] Haemanthus albiflos - image OK - top1=Aloe jucunda (83.02%)
# [303/349] Haemanthus albiflos - image OK - top1=Haemanthus albiflos (99.91%) ✅
# [304/349] Lithops geyeri - image OK - top1=Haemanthus albiflos (99.91%) ✅
# [304/349] Lithops geyeri - image OK - top1=Lithops geyeri (97.67%) ✅
# [305/349] Lithops hookeri - image OK - top1=Lithops geyeri (97.67%) ✅
# [305/349] Lithops hookeri - image OK - top1=Lithops geyeri (56.28%)
# [306/349] Pachypodium saundersii - image OK - top1=Lithops geyeri (56.28%)
# [306/349] Pachypodium saundersii - image OK - top1=Euphorbia (43.63%)
# [307/349] Curio ficoides - image OK - top1=Euphorbia (43.63%)
# [307/349] Curio ficoides - image OK - top1=Agave parrasana (37.60%)
# [308/349] Kleinia stapeliiformis - image OK - top1=Agave parrasana (37.60%)
# [308/349] Kleinia stapeliiformis - image OK - top1=Welwitschia mirabilis (21.70%)
# [309/349] Strelitzia juncea - image OK - top1=Welwitschia mirabilis (21.70%)
# [309/349] Strelitzia juncea - image OK - top1=Strelitzia juncea (100.00%) ✅
# [310/349] Tylecodon paniculatus - image OK - top1=Strelitzia juncea (100.00%) ✅
# [310/349] Tylecodon paniculatus - image OK - top1=Tylecodon paniculatus (98.14%) ✅
# [311/349] Welwitschia mirabilis - image OK - top1=Tylecodon paniculatus (98.14%) ✅
# [311/349] Welwitschia mirabilis - image OK - top1=Welwitschia mirabilis (99.00%) ✅
# [312/349] Begonia ruhlandiana - image OK - top1=Welwitschia mirabilis (99.00%) ✅
# [312/349] Begonia ruhlandiana - image OK - top1=Pavonia (70.78%)
# [313/349] Bromelia balansae - image OK - top1=Pavonia (70.78%)
# [313/349] Bromelia balansae - image OK - top1=Neoregelia (44.90%)
# [314/349] Cleistocactus - image OK - top1=Neoregelia (44.90%)
# [314/349] Cleistocactus - image OK - top1=Cleistocactus (95.79%) ✅
# [315/349] Copiapoa coquimbana - image OK - top1=Cleistocactus (95.79%) ✅
# [315/349] Copiapoa coquimbana - image OK - top1=Copiapoa coquimbana (74.37%) ✅
# [316/349] Copiapoa hypogaea - image OK - top1=Copiapoa coquimbana (74.37%) ✅
# [316/349] Copiapoa hypogaea - image OK - top1=Mammillaria (89.37%)
# [317/349] Copiapoa lembeckei - no wiki image
#  - image OK - top1=Mammillaria (89.37%)
# [317/349] Copiapoa lembeckei - no wiki image
# [318/349] Dyckia - image OK - top1=Vriesea (25.78%)
# [318/349] Dyckia - image OK - top1=Vriesea (25.78%)
# [319/349] Echinopsis huascha - image OK - top1=Echinopsis huascha (57.29%) ✅
# [319/349] Echinopsis huascha - image OK - top1=Echinopsis huascha (57.29%) ✅
# [320/349] Echinopsis - image OK - top1=Carnegiea gigantea (83.69%)
# [320/349] Echinopsis - image OK - top1=Carnegiea gigantea (83.69%)
# [321/349] Gymnocalycium saglionis - image OK - top1=Echinopsis (73.99%)
# [321/349] Gymnocalycium saglionis - image OK - top1=Echinopsis (73.99%)
# [322/349] Parodia magnifica - image OK - top1=Cleistocactus (53.87%)
# [322/349] Parodia magnifica - image OK - top1=Cleistocactus (53.87%)
# [323/349] Oreocereus trollii - image OK - top1=Oreocereus trollii (87.24%) ✅
# [323/349] Oreocereus trollii - image OK - top1=Oreocereus trollii (87.24%) ✅
# [324/349] Pilosocereus - image OK - top1=Pilosocereus (99.97%) ✅
# [324/349] Pilosocereus - image OK - top1=Pilosocereus (99.97%) ✅
# [325/349] Ubelmannia pectinifera - no wiki image
# [326/349] Aloe macrocarpa[325/349] Ubelmannia pectinifera - no wiki image
# [326/349] Aloe macrocarpa - image OK - top1=Aloe arborescens (58.53%)
# [327/349] Aloidendron dichotomum - image OK - top1=Aloe arborescens (58.53%)
# [327/349] Aloidendron dichotomum - image OK - top1=Aloidendron dichotomum (96.83%) ✅
# [328/349] Crassula - image OK - top1=Aloidendron dichotomum (96.83%) ✅
# [328/349] Crassula - image OK - top1=Vriesea (76.76%)
# [329/349] Dracaena hallii - image OK - top1=Vriesea (76.76%)
# [329/349] Dracaena hallii - image OK - top1=Amorphophallus bulbifer (28.67%)
# [330/349] Fockea edulis - image OK - top1=Amorphophallus bulbifer (28.67%)
# [330/349] Fockea edulis - image OK - top1=Graptopetalum (21.27%)
# [331/349] Haworthiopsis limifolia - image OK - top1=Graptopetalum (21.27%)
# [331/349] Haworthiopsis limifolia - image OK - top1=Haworthiopsis limifolia (83.92%) ✅
# [332/349] Parodia leninghausii - image OK - top1=Haworthiopsis limifolia (83.92%) ✅
# [332/349] Parodia leninghausii - image OK - top1=Parodia leninghausii (99.23%) ✅
# [333/349] Hemionitis bradburyi - no wiki image
#  - image OK - top1=Parodia leninghausii (99.23%) ✅
# [333/349] Hemionitis bradburyi - no wiki image
# [334/349] Pelargonium carnosum - no wiki image
# [335/349] Yucca baccata[334/349] Pelargonium carnosum - no wiki image
# [335/349] Yucca baccata - image OK - top1=Yucca baccata (97.69%) ✅
# [336/349] Leucophyllum frutescens - image OK - top1=Yucca baccata (97.69%) ✅
# [336/349] Leucophyllum frutescens - image OK - top1=Leucophyllum frutescens (99.69%) ✅
# [337/349] Agave lechuguilla - image OK - top1=Leucophyllum frutescens (99.69%) ✅
# [337/349] Agave lechuguilla - image OK - top1=Agave (74.15%)
# [338/349] Cylindropuntia - image OK - top1=Agave (74.15%)
# [338/349] Cylindropuntia - image OK - top1=Cylindropuntia (87.23%) ✅
# [339/349] Larrea tridentata - image OK - top1=Cylindropuntia (87.23%) ✅
# [339/349] Larrea tridentata - image OK - top1=Larrea tridentata (99.91%) ✅
# [340/349] Opuntia phaecantha - image OK - top1=Larrea tridentata (99.91%) ✅
# [340/349] Opuntia phaecantha - image OK - top1=Cylindropuntia (39.67%)
# [341/349] Opuntia santa-rita - image OK - top1=Cylindropuntia (39.67%)
# [341/349] Opuntia santa-rita - image OK - top1=Opuntia (72.33%)
# [342/349] Simmondsia chinensis - image OK - top1=Opuntia (72.33%)
# [342/349] Simmondsia chinensis - image OK - top1=Simmondsia chinensis (96.07%) ✅
# [343/349] Yucca faxoniana - image OK - top1=Simmondsia chinensis (96.07%) ✅
# [343/349] Yucca faxoniana - image OK - top1=Yucca elata (64.62%)
# [344/349] Opuntia basilaris - image OK - top1=Yucca elata (64.62%)
# [344/349] Opuntia basilaris - image OK - top1=Cylindropuntia (86.72%)
# [345/349] Opuntia basilaris hyb. - image OK - top1=Cylindropuntia (86.72%)
# [345/349] Opuntia basilaris hyb. - image OK - top1=Opuntia (82.10%)
# [346/349] Agave parrasana - image OK - top1=Opuntia (82.10%)
# [346/349] Agave parrasana - image OK - top1=Agave (96.09%)
# [347/349] Chilopsis linearis - image OK - top1=Agave (96.09%)
# [347/349] Chilopsis linearis - image OK - top1=Chilopsis linearis (47.04%) ✅
# [348/349] Euphorbia antisyphilitica - image OK - top1=Chilopsis linearis (47.04%) ✅
# [348/349] Euphorbia antisyphilitica - image OK - top1=Euphorbia antisyphilitica (99.99%) ✅
# [349/349] Euphorbia milii - image OK - top1=Euphorbia antisyphilitica (99.99%) ✅
# [349/349] Euphorbia milii - image OK - top1=Euphorbia milii (95.99%) ✅
#
# Done. Results saved to data/bioclip_wikipedia_eval.csv. Elapsed: 77.8s
#
# Summary:
#   total_species_evaluated: 349
#   total_with_images: 300
#   species_top1_count: 122
#   species_top3_count: 165
#   species_top5_count: 186
#   species_top1_acc: 0.407
#   species_top3_acc: 0.550
#   species_top5_acc: 0.620
#   genus_top1_count: 200
#   genus_top3_count: 237
#   genus_top5_count: 248
#   genus_top1_acc: 0.667
#   genus_top3_acc: 0.790
#   genus_top5_acc: 0.827
#   confidence_bins:
#     <0.6: count=95, species_top1_acc=0.168, genus_top1_acc=0.442
#     0.6-0.7: count=33, species_top1_acc=0.273, genus_top1_acc=0.636
#     0.7-0.8: count=29, species_top1_acc=0.276, genus_top1_acc=0.448
#     0.8-0.9: count=30, species_top1_acc=0.367, genus_top1_acc=0.667
#     >=0.9: count=113, species_top1_acc=0.690, genus_top1_acc=0.920
#  - image OK - top1=Euphorbia milii (95.99%) ✅
#
# Done. Results saved to data/bioclip_wikipedia_eval.csv. Elapsed: 77.8s
#
# Summary:
#   total_species_evaluated: 349
#   total_with_images: 300
#   species_top1_count: 122
#   species_top3_count: 165
#   species_top5_count: 186
#   species_top1_acc: 0.407
#   species_top3_acc: 0.550
#   species_top5_acc: 0.620
#   genus_top1_count: 200
#   genus_top3_count: 237
#   genus_top5_count: 248
#   genus_top1_acc: 0.667
#   genus_top3_acc: 0.790
#   genus_top5_acc: 0.827
#   confidence_bins:
#     <0.6: count=95, species_top1_acc=0.168, genus_top1_acc=0.442
#     0.6-0.7: count=33, species_top1_acc=0.273, genus_top1_acc=0.636
#     0.7-0.8: count=29, species_top1_acc=0.276, genus_top1_acc=0.448
#     0.8-0.9: count=30, species_top1_acc=0.367, genus_top1_acc=0.667
#     >=0.9: count=113, species_top1_acc=0.690, genus_top1_acc=0.920

# %%
# Preview a few rows from the saved CSV
r = pd.read_csv('data/bioclip_wikipedia_eval.csv')
r.head()
# Out:
#               plant_name  found_image  \
# 0    Adiantum peruvianum         True
# 1     Adiantum raddianum         True
# 2      Adiantum ternerum        False
# 3  Adiantum trapeziforme         True
# 4                Aechmea         True
#
#                                            thumbnail                top_1  \
# 0  https://upload.wikimedia.org/wikipedia/commons...  Adiantum peruvianum
# 1  https://upload.wikimedia.org/wikipedia/commons...   Adiantum raddianum
# 2                                                NaN                  NaN
# 3  https://upload.wikimedia.org/wikipedia/commons...  Adiantum peruvianum
# 4  https://upload.wikimedia.org/wikipedia/commons...     Aechmea fasciata
#
#    top_1_conf                                              top_5 fetch_method  \
# 0    0.999808  [('Adiantum peruvianum', 0.9998077750205994), ...        batch
# 1    0.732644  [('Adiantum raddianum', 0.7326443195343018), (...        batch
# 2    0.000000                                                 []          NaN
# 3    0.557934  [('Adiantum peruvianum', 0.5579341650009155), ...        batch
# 4    0.644700  [('Aechmea fasciata', 0.6446998119354248), ('A...        batch
#
#    top1_species_match  top3_species_match  top5_species_match  \
# 0                True                True                True
# 1                True                True                True
# 2               False               False               False
# 3               False                True                True
# 4               False                True                True
#
#    top1_genus_match  top3_genus_match  top5_genus_match
# 0              True              True              True
# 1              True              True              True
# 2             False             False             False
# 3              True              True              True
# 4              True              True              True
