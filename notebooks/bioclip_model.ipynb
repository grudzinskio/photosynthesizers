# %% [markdown]
# # BioClip Training

# %%
# (Optional) Install required packages if not present.
# Uncomment and run the next line in the notebook if you need to install dependencies.
# !pip install open_clip_torch pillow pandas requests

# %%
# Imports and note about model handling
import torch
from PIL import Image
import pandas as pd
import requests
from io import BytesIO
import time
import unicodedata
from typing import Optional, Dict, List

# Note: model loading and preprocessing are handled by `PlantClassifier` in `user-service/src/game_utils/plant_classifier.py`.
# This notebook will import and use `PlantClassifier.predict_image` for inference, so the notebook does not load BioCLIP directly.

# %%
# Load and clean plant names from CSV
plant_df = pd.read_csv('data/Plants_Formatted.csv', encoding='latin-1')

import re

def clean_scientific_name(s: str) -> str:
    """Normalize scientific names and remove cultivar/variety details.

    Follows the same intent as the project's `wikipediaApi.ts`:
    - Removes cultivar text in single quotes
    - Removes hybrid markers like " x "
    - Removes variety/subspecies markers (var., subsp., sub., forma)
    - If string contains ' sp.' or 'unknown', reduce to genus only
    - Normalize unicode and collapse whitespace
    """
    if not isinstance(s, str):
        s = str(s)
    s = s.strip()
    if not s:
        return s

    # Normalize unicode (remove accents)
    s = unicodedata.normalize('NFKD', s)
    s = ''.join(ch for ch in s if not unicodedata.combining(ch))

    # Remove weird replacement characters
    s = s.replace('\u2019', "'").replace('\u201c', '"').replace('\u201d', '"')

    # Remove any trailing or internal newlines
    s = s.replace('\n', ' ').replace('\r', ' ').strip()

    # Remove cultivar names in single quotes: "Genus species 'Cultivar'" -> "Genus species"
    if "'" in s:
        # remove the quote and everything after the first quote occurrence
        s = s.split("'")[0].strip()

    # Remove hybrid markers like ' x '
    if ' x ' in s:
        s = s.split(' x ')[0].strip()

    # Remove variety/subspecies markers
    markers = [' var. ', ' subsp. ', ' sub. ', ' forma ', ' f. ']
    for marker in markers:
        if marker in s:
            s = s.split(marker)[0].strip()

    # Handle 'sp.' or 'sp ' or 'unknown' -> return genus only
    if ' sp.' in s or re.search(r'\bsp\b', s, flags=re.IGNORECASE) or 'unknown' in s.lower():
        parts = s.split()
        s = parts[0] if parts else s

    # Collapse multiple spaces
    s = ' '.join(s.split())

    return s

# Some rows may have empty Scientific Name cells; drop those
plant_df['Scientific Name'] = plant_df['Scientific Name'].fillna('').astype(str)
all_names = [clean_scientific_name(x) for x in plant_df['Scientific Name'].tolist() if x.strip()!='']
# Deduplicate while preserving order
seen = set()
plant_names = []
# Keep a mapping to original names too (for evaluation display)
original_map = {}
for orig_raw in plant_df['Scientific Name'].tolist():
    orig = str(orig_raw) if not pd.isna(orig_raw) else ''
    cleaned = clean_scientific_name(orig)
    if cleaned and cleaned not in seen:
        seen.add(cleaned)
        plant_names.append(cleaned)
        original_map[cleaned] = orig

print(f'Unique species to evaluate: {len(plant_names)}')
plant_names[:10]
# Out:
# Unique species to evaluate: 349
# ['Adiantum peruvianum',
#  'Adiantum raddianum',
#  'Adiantum ternerum',
#  'Adiantum trapeziforme',
#  'Aechmea',
#  'Aechmea blanchetiana',
#  'Aechmea chantinii',
#  'Aechmea fasciata',
#  'Aechmea fulgens',
#  'Aechmea gamosepala']

# %%
# Example image preview (not preprocessed here)
# The notebook uses `PlantClassifier.predict_image(img_bytes)` for inference, so preprocessing is not required here.
from PIL import Image

# Example: open an image (no preprocessing) to inspect it in the notebook UI
img_path = 'data/example_images/Adiantum-peruvianum-Silver-Dollar-Fern-Amazon-Spheres.jpg.webp'
try:
    img = Image.open(img_path)
    img
except Exception as e:
    print('Could not open example image:', e)

# %%
# Improved Wikipedia fetching: session with retries, batch MediaWiki queries, and local cache
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
import os
import json
from urllib.parse import quote_plus

WIKI_REST_BASE = 'https://en.wikipedia.org/api/rest_v1/page/summary/'
WIKI_API_BASE = 'https://en.wikipedia.org/w/api.php'
HEADERS = {'User-Agent': 'BioCLIP-Eval/1.0 (Educational Project)', 'Accept': 'application/json'}

# Prepare a requests session with retries and backoff
session = requests.Session()
retry_strategy = Retry(
    total=5,
    backoff_factor=0.8,
    status_forcelist=[429, 500, 502, 503, 504],
    allowed_methods=frozenset(["HEAD", "GET", "OPTIONS"]),
)
adapter = HTTPAdapter(max_retries=retry_strategy)
session.mount("https://", adapter)
session.mount("http://", adapter)
session.headers.update(HEADERS)

# Local cache for wiki metadata and downloaded thumbnails
cache_path = 'data/wiki_cache.json'
img_cache_dir = 'data/wiki_images'
os.makedirs(img_cache_dir, exist_ok=True)

if os.path.exists(cache_path):
    try:
        with open(cache_path, 'r', encoding='utf-8') as fh:
            wiki_cache = json.load(fh)
    except Exception:
        wiki_cache = {}
else:
    wiki_cache = {}


def save_cache():
    try:
        with open(cache_path, 'w', encoding='utf-8') as fh:
            json.dump(wiki_cache, fh, ensure_ascii=False, indent=2)
    except Exception:
        pass


def slugify_name(name: str) -> str:
    return ''.join(c if c.isalnum() or c in (' ', '-', '_') else '_' for c in name).replace(' ', '_')[:200]


def batch_query_pageimages(names: list, batch_size: int = 50) -> Dict[str, Dict]:
    """Query MediaWiki action=query in batches to get thumbnails for many titles at once.

    Returns a mapping from requested-name -> dict(title, thumbnail, url) for those that had thumbnails.
    """
    mapping = {}
    for i in range(0, len(names), batch_size):
        batch = names[i:i+batch_size]
        titles = '|'.join(batch)
        params = {
            'action': 'query',
            'titles': titles,
            'prop': 'pageimages',
            'pithumbsize': 1000,
            'redirects': 1,
            'format': 'json'
        }
        try:
            resp = session.get(WIKI_API_BASE, params=params, timeout=15)
            if resp.status_code != 200:
                time.sleep(0.1)
                continue
            data = resp.json()
            query = data.get('query', {})
            pages = query.get('pages', {})
            # Build normalized/redirect maps
            norm_map = {n['from']: n['to'] for n in query.get('normalized', [])} if query.get('normalized') else {}
            redir_map = {r['from']: r['to'] for r in query.get('redirects', [])} if query.get('redirects') else {}

            # title -> page mapping
            title_to_page = {page.get('title', ''): page for page in pages.values()}

            for requested in batch:
                mapped = requested
                if requested in norm_map:
                    mapped = norm_map[requested]
                if requested in redir_map:
                    mapped = redir_map[requested]

                page = title_to_page.get(mapped)
                if page:
                    thumb = page.get('thumbnail', {}).get('source', '')
                    if thumb:
                        mapping[requested] = {
                            'title': page.get('title', ''),
                            'thumbnail': thumb,
                            'url': f"https://en.wikipedia.org/?curid={page.get('pageid')}"
                        }
        except Exception:
            # on any error, wait and continue
            time.sleep(0.2)
            continue
        # brief pause between batches
        time.sleep(0.1)
    return mapping


def get_wikipedia_summary_with_thumbnail(scientific_name: str, timeout: int = 10) -> Optional[Dict]:
    """Fallback single-name fetch using REST summary endpoint (used only when batch lookup didn't find a thumbnail).
    Returns dict with title, extract, url, thumbnail or None.
    """
    try:
        encoded = requests.utils.quote(scientific_name)
        resp = session.get(f'{WIKI_REST_BASE}{encoded}', timeout=timeout)
        if resp.status_code == 200:
            data = resp.json()
            thumbnail = data.get('thumbnail', {}).get('source', '') if isinstance(data.get('thumbnail'), dict) else ''
            return {
                'title': data.get('title', ''),
                'extract': data.get('extract', ''),
                'url': data.get('content_urls', {}).get('desktop', {}).get('page', ''),
                'thumbnail': thumbnail,
            }
        else:
            return None
    except Exception:
        return None


def download_image_bytes(url: str, timeout: int = 10, attempts: int = 3) -> Optional[bytes]:
    """Download image bytes with retries using the session. Skips SVG/XML content types.
    """
    for attempt in range(attempts):
        try:
            r = session.get(url, timeout=timeout, stream=True)
            if r.status_code == 200:
                content_type = r.headers.get('Content-Type', '').lower()
                if 'svg' in content_type or 'xml' in content_type:
                    return None
                data = r.content
                if data:
                    return data
            else:
                # pause and retry
                time.sleep(0.5 * (attempt + 1))
        except Exception:
            time.sleep(0.5 * (attempt + 1))
            continue
    return None

# %% [markdown]
# ## Test Plant Classifier Class

# %%
# Evaluate across all plant names using cached thumbnails and batch MediaWiki lookup
results = []
start = time.time()

# Attempt to load an Excel file using the project's admin-service ExcelLoaderService
# Falls back to the deduplicated `plant_names` if no Excel file is found or import fails.
import sys, glob
dome_map = {}
try:
    sys.path.insert(0, 'admin-service/src')
    from excel_loader_service import ExcelLoaderService
    loader = ExcelLoaderService()
    # Prefer any .xlsx/.xls files found in data/
    candidates = glob.glob('data/*.xls*')
    if candidates:
        excel_path = candidates[0]
        print(f'Loading Excel file: {excel_path}')
        with open(excel_path, 'rb') as fh:
            content = fh.read()
        res = loader.load_excel_file(content)
        if res.get('success'):
            dome_names = loader.get_all_domes()
            for d in dome_names:
                df = loader.get_dome_dataframe(d)
                if df is None:
                    dome_map[d] = []
                    continue
                # Extract and clean scientific names for this dome
                names = df['Scientific Name'].fillna('').astype(str).tolist() if 'Scientific Name' in df.columns else []
                cleaned = [clean_scientific_name(x) for x in names if str(x).strip()!='']
                # Deduplicate while preserving order per-dome
                seen = set(); uniq = []
                for n in cleaned:
                    if n and n not in seen:
                        seen.add(n); uniq.append(n)
                dome_map[d] = uniq
        else:
            print('Excel loader returned error, falling back to CSV list')
            dome_map = {'All': plant_names}
    else:
        print('No Excel files found in data/, falling back to CSV list')
        dome_map = {'All': plant_names}
except Exception as e:
    print('Could not import or load Excel loader, falling back to CSV list:', e)
    dome_map = {'All': plant_names}

# Prepare classifier from user-service
classifier = None
try:
    sys.path.insert(0, 'user-service/src')
    from game_utils.plant_classifier import PlantClassifier
    classifier = PlantClassifier()
    print('Loaded PlantClassifier from user-service (will use its text features).')
except Exception as e:
    print('ERROR: could not import PlantClassifier from user-service:', e)
    raise

# 1) Use batch MediaWiki query to get thumbnails for many species at once
print('Running batch MediaWiki pageimages lookup for all unique titles...')
# Build a global list of unique titles to batch-query (include genus fallbacks too), skip 'All' combined dome
all_titles = set()
for d, names in dome_map.items():
    if d == 'All':
        continue
    for n in names:
        if n:
            all_titles.add(n)
            # add genus as candidate lookup too
            parts = n.split()
            if parts:
                all_titles.add(parts[0])
all_titles = list(all_titles)
batch_map = batch_query_pageimages(all_titles, batch_size=50)
print(f'Batch lookup returned thumbnails for {len(batch_map)} titles')

# Helper to get genus from a scientific name
def genus_of(name: str) -> str:
    parts = str(name).split()
    return parts[0] if parts else ''

# Evaluate per-dome (skip 'All' because we evaluate individual domes already)
for dome_name, names in dome_map.items():
    if dome_name == 'All':
        print(f"Skipping combined dome 'All' (per-dome evaluations performed)")
        continue
    print('\n' + '='*60)
    print(f"Evaluating dome: {dome_name} ({len(names)} species)")
    print('='*60)
    for i, pname in enumerate(names):
        print(f'[{dome_name} {i+1}/{len(names)}] {pname}', end='')

        # If cached and already has thumbnail stored, reuse
        cache_entry = wiki_cache.get(pname)
        if cache_entry and cache_entry.get('thumbnail'):
            thumb = cache_entry['thumbnail']
            fetch_method = cache_entry.get('fetch_method', 'cache')
        else:
            # Try batch_map first
            meta = batch_map.get(pname)
            fetch_method = None
            if meta and meta.get('thumbnail'):
                thumb = meta['thumbnail']
                fetch_method = 'batch'
            else:
                # Try genus (if different)
                genus = pname.split()[0] if pname.split() else pname
                meta_genus = batch_map.get(genus)
                if meta_genus and meta_genus.get('thumbnail'):
                    thumb = meta_genus['thumbnail']
                    fetch_method = 'batch_genus'
                else:
                    # Finally, try REST summary per-name as fallback
                    wiki = get_wikipedia_summary_with_thumbnail(pname)
                    if wiki and wiki.get('thumbnail'):
                        thumb = wiki['thumbnail']
                        fetch_method = 'rest'
                    else:
                        thumb = ''

            # Save to cache placeholder (we'll enrich later if we download image)
            wiki_cache[pname] = {'thumbnail': thumb, 'fetch_method': fetch_method}
            save_cache()

        if not thumb:
            print(' - no wiki image')
            results.append({
                'plant_name': pname,
                'Dome': dome_name,
                'found_image': False,
                'thumbnail': '',
                'top_1': '',
                'top_1_conf': 0.0,
                'top_5': [],
                'fetch_method': fetch_method,
                'top1_species_match': False,
                'top3_species_match': False,
                'top5_species_match': False,
                'top1_genus_match': False,
                'top3_genus_match': False,
                'top5_genus_match': False,
            })
            # polite sleep
            time.sleep(0.12)
            continue

        # If we've already downloaded this thumbnail image locally, reuse it
        slug = slugify_name(pname)
        img_path = os.path.join(img_cache_dir, f"{slug}.jpg")
        if os.path.exists(img_path):
            with open(img_path, 'rb') as f:
                img_bytes = f.read()
        else:
            img_bytes = download_image_bytes(thumb)
            if img_bytes:
                try:
                    with open(img_path, 'wb') as f:
                        f.write(img_bytes)
                except Exception:
                    pass

        if not img_bytes:
            print(' - failed download')
            # update cache to mark failure and continue
            wiki_cache[pname] = {'thumbnail': thumb, 'fetch_method': fetch_method, 'downloaded': False}
            save_cache()
            results.append({
                'plant_name': pname,
                'Dome': dome_name,
                'found_image': False,
                'thumbnail': thumb,
                'top_1': '',
                'top_1_conf': 0.0,
                'top_5': [],
                'fetch_method': fetch_method,
                'top1_species_match': False,
                'top3_species_match': False,
                'top5_species_match': False,
                'top1_genus_match': False,
                'top3_genus_match': False,
                'top5_genus_match': False,
            })
            time.sleep(0.12)
            continue

        # Use PlantClassifier to predict from image bytes
        try:
            res = classifier.predict_image(img_bytes)
            top1_name = res.get('plant_name', '')
            top1_conf = res.get('confidence', 0.0)
            top5 = res.get('top_5', [])
            # Ensure top5 is in the (name, prob) format
            if isinstance(top5, list) and top5 and not isinstance(top5[0], tuple):
                # if classifier returned list-like not tuples, try to coerce
                top5 = [(str(x[0]), float(x[1])) for x in top5]
        except Exception as e:
            print(' - classifier error', e)
            wiki_cache[pname] = {'thumbnail': thumb, 'fetch_method': fetch_method, 'downloaded': False}
            save_cache()
            results.append({
                'plant_name': pname,
                'Dome': dome_name,
                'found_image': False,
                'thumbnail': thumb,
                'top_1': '',
                'top_1_conf': 0.0,
                'top_5': [],
                'fetch_method': fetch_method,
                'top1_species_match': False,
                'top3_species_match': False,
                'top5_species_match': False,
                'top1_genus_match': False,
                'top3_genus_match': False,
                'top5_genus_match': False,
            })
            time.sleep(0.12)
            continue

        top_names = [t[0] for t in top5]

        # Species-level matches
        top1_species_match = (top1_name == pname)
        top3_species_match = any((name == pname) for name in top_names[:3])
        top5_species_match = any((name == pname) for name in top_names[:5])

        # Genus-level matches: compare genus (first token)
        true_genus = genus_of(pname)
        pred_genera = [genus_of(n) for n in top_names]
        top1_genus_match = (pred_genera[0] == true_genus) if pred_genera else False
        top3_genus_match = any((g == true_genus) for g in pred_genera[:3])
        top5_genus_match = any((g == true_genus) for g in pred_genera[:5])

        correct = top1_species_match
        print(f' - top1={top1_name} ({top1_conf*100:.2f}%)' + ( ' ✅' if correct else '' ))

        # update cache
        try:
            wiki_cache[pname].update({'downloaded': True, 'local_path': img_path, 'title': wiki_cache.get(pname, {}).get('title', '')})
            save_cache()
        except Exception:
            pass

        results.append({
            'plant_name': pname,
            'Dome': dome_name,
            'found_image': True,
            'thumbnail': thumb,
            'top_1': top1_name,
            'top_1_conf': float(top1_conf),
            'top_5': top5,
            'fetch_method': fetch_method,
            'top1_species_match': top1_species_match,
            'top3_species_match': top3_species_match,
            'top5_species_match': top5_species_match,
            'top1_genus_match': top1_genus_match,
            'top3_genus_match': top3_genus_match,
            'top5_genus_match': top5_genus_match,
        })

        # polite sleep between processing items
        time.sleep(0.12)

# Save results to CSV and show summary
out_df = pd.DataFrame(results)

# Compute overall metrics (consider only rows where found_image==True)
# Make an explicit copy to avoid SettingWithCopyWarning when assigning new columns
with_images_df = out_df[out_df['found_image'] == True].copy()
num_with_images = len(with_images_df)
num_total = len(out_df)

summary = {
    'total_species_evaluated': num_total,
    'total_with_images': num_with_images,
}

if num_with_images > 0:
    summary.update({
        'species_top1_count': int(with_images_df['top1_species_match'].sum()),
        'species_top3_count': int(with_images_df['top3_species_match'].sum()),
        'species_top5_count': int(with_images_df['top5_species_match'].sum()),
        'species_top1_acc': float(with_images_df['top1_species_match'].sum() / num_with_images),
        'species_top3_acc': float(with_images_df['top3_species_match'].sum() / num_with_images),
        'species_top5_acc': float(with_images_df['top5_species_match'].sum() / num_with_images),
        'genus_top1_count': int(with_images_df['top1_genus_match'].sum()),
        'genus_top3_count': int(with_images_df['top3_genus_match'].sum()),
        'genus_top5_count': int(with_images_df['top5_genus_match'].sum()),
        'genus_top1_acc': float(with_images_df['top1_genus_match'].sum() / num_with_images),
        'genus_top3_acc': float(with_images_df['top3_genus_match'].sum() / num_with_images),
        'genus_top5_acc': float(with_images_df['top5_genus_match'].sum() / num_with_images),
    })

# Per-dome summaries
per_dome = {}
for dname, df_grp in with_images_df.groupby('Dome'):
    count = len(df_grp)
    per_dome[dname] = {
        'count_with_images': int(count),
        'species_top1_count': int(df_grp['top1_species_match'].sum()),
        'species_top1_acc': float(df_grp['top1_species_match'].sum() / count) if count>0 else None,
        'genus_top1_count': int(df_grp['top1_genus_match'].sum()),
        'genus_top1_acc': float(df_grp['top1_genus_match'].sum() / count) if count>0 else None,
    }
summary['per_dome'] = per_dome

# --- New: Accuracy by confidence bins (top-1 predicted confidence)
# Define bins (upper-inclusive for the top interval)
bin_edges = [0.0, 0.6, 0.7, 0.8, 0.9, 1.0]
bin_labels = ['<0.6', '0.6-0.7', '0.7-0.8', '0.8-0.9', '>=0.9']

# Ensure top_1_conf is numeric and within [0,1] (use .loc to assign explicitly)
with_images_df.loc[:, 'top_1_conf'] = with_images_df['top_1_conf'].fillna(0.0).astype(float).clip(0.0, 1.0)

# Categorize into bins (assign via .loc to avoid chained-assignment warnings)
with_images_df.loc[:, 'conf_bin'] = pd.cut(with_images_df['top_1_conf'], bins=bin_edges, labels=bin_labels, include_lowest=True, right=False)

# Compute metrics per bin (overall)
conf_summary = []
for label in bin_labels:
    bin_df = with_images_df[with_images_df['conf_bin'] == label]
    cnt = len(bin_df)
    if cnt == 0:
        conf_summary.append({
            'conf_bin': label,
            'count': 0,
            'species_top1_acc': None,
            'genus_top1_acc': None
        })
        continue
    species_correct = int(bin_df['top1_species_match'].sum())
    genus_correct = int(bin_df['top1_genus_match'].sum())
    conf_summary.append({
        'conf_bin': label,
        'count': cnt,
        'species_top1_acc': float(species_correct / cnt),
        'genus_top1_acc': float(genus_correct / cnt)
    })

# Add conf_summary to summary dict and also print table
summary['confidence_bins'] = conf_summary

out_path = 'data/bioclip_wikipedia_eval.csv'
out_df.to_csv(out_path, index=False)

elapsed = time.time() - start
print(f"\nDone. Results saved to {out_path}. Elapsed: {elapsed:.1f}s")

# Print summary nicely
print('\nSummary:')
for k, v in summary.items():
    if k == 'confidence_bins':
        print('  confidence_bins:')
        for b in v:
            if b['count'] == 0:
                print(f"    {b['conf_bin']}: count=0")
            else:
                print(f"    {b['conf_bin']}: count={b['count']}, species_top1_acc={b['species_top1_acc']:.3f}, genus_top1_acc={b['genus_top1_acc']:.3f}")
    elif k == 'per_dome':
        print('  per_dome:')
        for dn, dv in v.items():
            s_acc = f"{dv['species_top1_acc']:.3f}" if dv['species_top1_acc'] is not None else 'N/A'
            g_acc = f"{dv['genus_top1_acc']:.3f}" if dv['genus_top1_acc'] is not None else 'N/A'
            print(f"    {dn}: count_with_images={dv['count_with_images']}, species_top1_acc={s_acc}, genus_top1_acc={g_acc}")
    elif isinstance(v, float):
        print(f'  {k}: {v:.3f}')
    else:
        print(f'  {k}: {v}')
# Out:
# Loading Excel file: data\Plant Collection Inventory and Move Management.xlsx
# Excel parsing complete:
#   Total domes found: 2
#   Tropical Dome: 463 plants
#   Desert Dome: 435 plants
#   Total plants (excluding 'All'): 898
#   'All' combined: 898 plants
# Loading BioCLIP model...
# Using device: cpu
# Loading plants from database...
# Found 898 plants in database
# Text features precomputed and cached!
# BioCLIP model loaded! 898 plants indexed.
# Loaded PlantClassifier from user-service (will use its text features).
# Running batch MediaWiki pageimages lookup for all unique titles...
# Batch lookup returned thumbnails for 795 titles
#
# ============================================================
# Evaluating dome: Tropical Dome (376 species)
# ============================================================
# [Tropical Dome 1/376] Acalypha hispida - top1=Acalypha hispida (99.99%) ✅
# [Tropical Dome 2/376] Acca selloiana - no wiki image
# [Tropical Dome 3/376] Achimenantha - no wiki image
# [Tropical Dome 4/376] Adiantum peruvianum - top1=Adiantum peruvianum (99.98%) ✅
# [Tropical Dome 5/376] Adiantum raddianum - top1=Adiantum raddianum (75.64%) ✅
# [Tropical Dome 6/376] Adiantum ternerum - top1=Adiantum peruvianum (29.07%)
# [Tropical Dome 7/376] Adiantum trapeziforme - top1=Adiantum peruvianum (51.16%)
# [Tropical Dome 8/376] Adonidia merrillii - top1=Dracaena hallii (33.63%)
# [Tropical Dome 9/376] Aechmea - top1=Agave americana subsp. americana (77.90%)
# [Tropical Dome 10/376] Aechmea blanchetiana - top1=Cordyline fruticosa 'Ruby' (93.36%)
# [Tropical Dome 11/376] Aechmea chantinii - top1=Vriesea simplex x mariae (48.85%)
# [Tropical Dome 12/376] Aechmea fasciata - top1=Aechmea fasciata (83.06%) ✅
# [Tropical Dome 13/376] Aechmea fulgens - top1=Aechmea miniata (73.40%)
# [Tropical Dome 14/376] Aechmea gamosepala - top1=Aechmea gamosepala (70.00%) ✅
# [Tropical Dome 15/376] Aechmea miniata - top1=Billbergia pyramidalis 'Kyoto' (68.77%)
# [Tropical Dome 16/376] Aeschynanthus pulcher - top1=Aeschynanthus pulcher (99.35%) ✅
# [Tropical Dome 17/376] Aglaonema - top1=Philodendron x 'Moonlight' (26.28%)
# [Tropical Dome 18/376] Aglaonema commutatum - top1=Dieffenbachia seguine 'Tropic Snow' (29.01%)
# [Tropical Dome 19/376] Alocasia - top1=Alocasia macrorrhizos 'Stingray' (53.94%)
# [Tropical Dome 20/376] Alocasia macrorrhizos - top1=Alocasia macrorrhizos 'Stingray' (52.66%)
# [Tropical Dome 21/376] Alocasia baginda - top1=Anthurium andraeanum 'Utah' (52.94%)
# [Tropical Dome 22/376] Alocasia heterophylla - top1=Syngonium podophyllum (30.79%)
# [Tropical Dome 23/376] Alocasia longiloba - top1=Anthurium clarinervium (21.24%)
# [Tropical Dome 24/376] Alocasia micholitziana - top1=Alocasia macrorrhizos 'Stingray' (71.57%)
# [Tropical Dome 25/376] Alocasia portei - top1=Alocasia portei (67.10%) ✅
# [Tropical Dome 26/376] Alocasia reginula - top1=Alocasia reginula 'Black Velvet' (86.09%)
# [Tropical Dome 27/376] Alocasia zebrina - top1=Chamaedorea metallica (37.13%)
# [Tropical Dome 28/376] Alpinia nutans - top1=Hedychium coronarium (94.10%)
# [Tropical Dome 29/376] Alpinia officinarum - top1=Crinum procumbens var. splendens (36.98%)
# [Tropical Dome 30/376] Alpinia purpurata - top1=Alpinia purpurata (37.88%) ✅
# [Tropical Dome 31/376] Alpinia vittata - top1=Cordyline fruticosa 'Ruby' (84.08%)
# [Tropical Dome 32/376] Alpinia zerumbet - top1=Philodendron hastatum 'Silver Sword' (17.29%)
# [Tropical Dome 33/376] Alsophila australis - top1=Marcgravia sp. (64.70%)
# [Tropical Dome 34/376] Alternanthera ficoidea - top1=Hymenocallis caribaea (78.85%)
# [Tropical Dome 35/376] Amorphophallus bulbifer - top1=Amorphophallus bulbifer (56.20%) ✅
# [Tropical Dome 36/376] Amorphophallus konjac - top1=Anthurium andraeanum (44.28%)
# [Tropical Dome 37/376] Amorphophallus titanum - top1=Amorphophallus titanum (99.91%) ✅
# [Tropical Dome 38/376] Ananas comosus - top1=Ananas comosus (97.22%) ✅
# [Tropical Dome 39/376] Annona cherimola - top1=Annona muricata (29.51%)
# [Tropical Dome 40/376] Annona muricata - top1=Annona muricata (99.97%) ✅
# [Tropical Dome 41/376] Anthurium - top1=Anthurium andraeanum (99.80%)
# [Tropical Dome 42/376] Anthurium andraeanum - top1=Anthurium andraeanum (97.49%) ✅
# [Tropical Dome 43/376] Anthurium atropurpureum - top1=Anthurium andraeanum (99.80%)
# [Tropical Dome 44/376] Anthurium clarinervium - top1=Anthurium clarinervium (95.35%) ✅
# [Tropical Dome 45/376] Anthurium ensifolium - top1=Anthurium andraeanum (99.80%)
# [Tropical Dome 46/376] Anthurium forgetii - top1=Anthurium forgetii (77.73%) ✅
# [Tropical Dome 47/376] Anthurium gracile - top1=Anthurium andraeanum 'Utah' (44.23%)
# [Tropical Dome 48/376] Anthurium grandifolium - top1=Anthurium andraeanum (99.80%)
# [Tropical Dome 49/376] Anthurium hybrid - top1=Anthurium andraeanum (99.80%)
# [Tropical Dome 50/376] Anthurium magnificum - top1=Anthurium magnificum (96.45%) ✅
# [Tropical Dome 51/376] Anthurium pedatoradiatum - top1=Anthurium podophyllum (94.09%)
# [Tropical Dome 52/376] Anthurium pentaphyllum - top1=Anthurium pentaphyllum (99.94%) ✅
# [Tropical Dome 53/376] Anthurium plowmanii - top1=Anthurium andraeanum (99.80%)
# [Tropical Dome 54/376] Anthurium podophyllum - top1=Anthurium podophyllum (99.96%) ✅
# [Tropical Dome 55/376] Anthurium veitchii - top1=Anthurium veitchii (80.29%) ✅
# [Tropical Dome 56/376] Anthurium vittarifolium - top1=Hedychium coccineum (86.44%)
# [Tropical Dome 57/376] Anthurium willdenowii - top1=Anthurium andraeanum (99.80%)
# [Tropical Dome 58/376] Aphelandra sinclairiana - top1=Acalypha hispida (33.24%)
# [Tropical Dome 59/376] Arachniodes simplicior - top1=Davallia  fejeensis (66.56%)
# [Tropical Dome 60/376] Arachnothryx leucophylla - top1=Clerodendrum nutans (88.82%)
# [Tropical Dome 61/376] Aristolochia trilobata - top1=Aristolochia trilobata (42.85%) ✅
# [Tropical Dome 62/376] Artocarpus altilis - top1=Gomphocarpus physocarpus (32.83%)
# [Tropical Dome 63/376] Asclepias curassavica - top1=Asclepias curassavica (99.78%) ✅
# [Tropical Dome 64/376] Asparagus densiflorus - top1=Asparagus sp. (38.93%)
# [Tropical Dome 65/376] Asparagus - no wiki image
# [Tropical Dome 66/376] Aspidistra elatior - top1=Alpinia zerumbet (85.38%)
# [Tropical Dome 67/376] Asplenium nidus - top1=Asplenium nidus (100.00%) ✅
# [Tropical Dome 68/376] Asplenium x - top1=Adiantum peruvianum (79.14%)
# [Tropical Dome 69/376] Averrhoa carambola - top1=Averrhoa carambola 'Arkin' (90.22%)
# [Tropical Dome 70/376] Azadirachta indica - top1=Ficus religiosa (35.95%)
# [Tropical Dome 71/376] Bacopa caroliniana - top1=Bacopa caroliniana (57.39%) ✅
# [Tropical Dome 72/376] Barleria cristata - top1=Barleria cristata (92.75%) ✅
# [Tropical Dome 73/376] Barleria oenotheroides - top1=Barleria cristata (41.13%)
# [Tropical Dome 74/376] Barleria repens - top1=Begonia coccinea (39.05%)
# [Tropical Dome 75/376] Bauhinia purpurea - top1=Bauhinia purpurea (99.63%) ✅
# [Tropical Dome 76/376] Begonia - top1=Begonia coccinea (88.75%)
# [Tropical Dome 77/376] Begonia cleopatrae - top1=Begonia coccinea (88.75%)
# [Tropical Dome 78/376] Begonia coccinea - top1=Begonia coccinea (46.83%) ✅
# [Tropical Dome 79/376] Begonia convolvulacea - top1=Begonia coccinea (88.75%)
# [Tropical Dome 80/376] Bignonia argyreoviolascens - top1=Annona cherimola (33.36%)
# [Tropical Dome 81/376] Billbergia - top1=Neoregelia carolinae (20.44%)
# [Tropical Dome 82/376] Billbergia chlorostica - top1=Neoregelia carolinae (20.44%)
# [Tropical Dome 83/376] Billbergia nutans - top1=Billbergia nutans (95.65%) ✅
# [Tropical Dome 84/376] Billbergia pyramidalis - top1=Aechmea 'Blue Tango' (46.74%)
# [Tropical Dome 85/376] Blighia sapida - top1=Psidium guajava (68.92%)
# [Tropical Dome 86/376] Bosenbergia rotunda - no wiki image
# [Tropical Dome 87/376] Brunfelsia gigantea - top1=Thunbergia erecta (67.42%)
# [Tropical Dome 88/376] Brunfelsia uniflora - top1=Brunfelsia gigantea (95.17%)
# [Tropical Dome 89/376] Bulnesia arborea - top1=Tamarindus indica (30.37%)
# [Tropical Dome 90/376] Bunchosia argentea - top1=Ficus lutea (59.19%)
# [Tropical Dome 91/376] Caladium - top1=Piper nigrum (94.02%)
# [Tropical Dome 92/376] Caladium bicolor - top1=Aspidistra elatior 'Asahi' (77.66%)
# [Tropical Dome 93/376] Caladium praetermissum - top1=Alocasia macrorrhizos 'Stingray' (36.86%)
# [Tropical Dome 94/376] Goeppertia bella - top1=Dieffenbachia  seguine 'Tiki' (31.12%)
# [Tropical Dome 95/376] Calathea crotalifera - top1=Goeppertia ornata 'Rosea-lineata' (39.42%)
# [Tropical Dome 96/376] Goeppertia insignis - top1=Asplenium nidus (37.94%)
# [Tropical Dome 97/376] Goeppertia louisae - top1=Goeppertia louisae (90.90%) ✅
# [Tropical Dome 98/376] Goeppertia majestica - top1=Goeppertia ornata 'Rosea-lineata' (24.63%)
# [Tropical Dome 99/376] Goeppertia makoyana - top1=Goeppertia makoyana (99.50%) ✅
# [Tropical Dome 100/376] Goeppertia ornata - top1=Goeppertia bella (58.69%)
# [Tropical Dome 101/376] Goeppertia roseopicta - top1=Goeppertia louisae (87.31%)
# [Tropical Dome 102/376] Goeppertia zebrina - top1=Goeppertia louisae (78.61%)
# [Tropical Dome 103/376] Calliandra tergemina - top1=Calliandra eriophylla (83.73%)
# [Tropical Dome 104/376] Campyloneurum aglaolepis - top1=Microsorum punctatum 'Serratum' (61.78%)
# [Tropical Dome 105/376] Cananga odorata - top1=Musa acuminata 'Rajapuri' (27.23%)
# [Tropical Dome 106/376] Ceratozamia mexicana - top1=Phoenix roebelenii (68.66%)
# [Tropical Dome 107/376] Ceratozamia robusta - top1=Ceratozamia robusta (91.31%) ✅
# [Tropical Dome 108/376] Chamaedorea elegans - top1=Chamaedorea elegans (96.90%) ✅
# [Tropical Dome 109/376] Chamaedorea metallica - top1=Dieffenbachia seguine 'Splash' (47.71%)
# [Tropical Dome 110/376] Chlorophytum comosum - top1=Dracaena fragrans (58.09%)
# [Tropical Dome 111/376] Chlorophytum filipendulum - top1=Dracaena fragrans 'Santa Rosa' (65.53%)
# [Tropical Dome 112/376] Chondrodendron tomentosum - top1=Theobroma cacao (85.47%)
# [Tropical Dome 113/376] Citrus medica - top1=Citrus medica (95.07%) ✅
# [Tropical Dome 114/376] Citrus sinensis - top1=Citrus medica (92.49%)
# [Tropical Dome 115/376] Citrus - top1=Citrus medica (92.49%)
# [Tropical Dome 116/376] Clerodendrum nutans - top1=Clerodendrum thomsoniae (67.66%)
# [Tropical Dome 117/376] Clerodendrum quadriloculare - top1=Clerodendrum quadriloculare (94.85%) ✅
# [Tropical Dome 118/376] Clerodendrum thomsoniae - top1=Clerodendrum thomsoniae (99.99%) ✅
# [Tropical Dome 119/376] Clusia orthoneura - top1=Etlingera elatior (83.38%)
# [Tropical Dome 120/376] Cocos nucifera - top1=Cocos nucifera (73.47%) ✅
# [Tropical Dome 121/376] Codiaeum variegatum - top1=Codiaeum variegatum 'Mammy' (82.65%)
# [Tropical Dome 122/376] Coffea arabica - top1=Coffea arabica (91.09%) ✅
# [Tropical Dome 123/376] Cola acuminata - top1=Theobroma cacao (94.50%)
# [Tropical Dome 124/376] Colocasia - top1=Colocasia 'Cophama' (38.93%)
# [Tropical Dome 125/376] Colocasia esculenta - top1=Alocasia macrorrhizos 'Stingray' (68.40%)
# [Tropical Dome 126/376] Colocasia fallax - top1=Alocasia longiloba (28.81%)
# [Tropical Dome 127/376] Colysis wrightii - top1=Campyloneurum aglaolepis (49.96%)
# [Tropical Dome 128/376] Cordyline australis - top1=Dracaena reflexa (65.51%)
# [Tropical Dome 129/376] Cordyline fruticosa - top1=Cordyline fruticosa (82.79%) ✅
# [Tropical Dome 130/376] Costus guanaiensis - top1=Heliconia stricta 'Dwarf Jamaican' (28.55%)
# [Tropical Dome 131/376] Costus afer - top1=Goeppertia zebrina (50.62%)
# [Tropical Dome 132/376] Costus woodsonii - top1=Heliconia stricta 'Dwarf Jamaican' (22.99%)
# [Tropical Dome 133/376] Couroupita guianensis - top1=Couroupita guianensis (78.68%) ✅
# [Tropical Dome 134/376] Crescentia cujete - top1=Crescentia cujete (74.59%) ✅
# [Tropical Dome 135/376] Crinum asiaticum - top1=Crinum asiaticum (99.74%) ✅
# [Tropical Dome 136/376] Crinum procumbens - top1=Clerodendrum quadriloculare (80.06%)
# [Tropical Dome 137/376] Crinum - top1=Clerodendrum quadriloculare (80.06%)
# [Tropical Dome 138/376] Crossandra infundibuliformis - top1=Crossandra infundibuliformis (83.44%) ✅
# [Tropical Dome 139/376] Cryptanthus - top1=Dracaena trifasciata (39.39%)
# [Tropical Dome 140/376] Cryptanthus hybrid - top1=Dracaena trifasciata (39.39%)
# [Tropical Dome 141/376] Cryptanthus nubicola - top1=Dracaena trifasciata (39.39%)
# [Tropical Dome 142/376] Ctenanthe marantifolia - top1=Peperomia obtusifolia 'Marble' (69.60%)
# [Tropical Dome 143/376] Cubanola domingensis - top1=Cephalocereus senilis (40.19%)
# [Tropical Dome 144/376] Curcuma alismatifolia - top1=Mansoa alliacea (60.69%)
# [Tropical Dome 145/376] Curcuma longa - top1=Thunbergia erecta (57.47%)
# [Tropical Dome 146/376] Curcuma rubescens - top1=Alpinia zerumbet (34.96%)
# [Tropical Dome 147/376] Cycas rumphii - top1=Cycas rumphii (73.57%) ✅
# [Tropical Dome 148/376] Cyperus alternifolius - top1=Cyperus alternifolius (92.36%) ✅
# [Tropical Dome 149/376] Cyrtomium falcatum - top1=Sauromatum venosum (99.77%)
# [Tropical Dome 150/376] Davallia fejeensis - top1=Swietenia macrophylla (53.76%)
# [Tropical Dome 151/376] Davallia solida - top1=Asplenium x 'Austral Gem' (53.76%)
# [Tropical Dome 152/376] Derris elliptica - top1=Ariocarpus fissuratus (83.62%)
# [Tropical Dome 153/376] Dichorisandra thyrsiflora - top1=Dichorisandra thyrsiflora (40.91%) ✅
# [Tropical Dome 154/376] Didymochlaena truncatula - top1=Nephrolepis exaltata (69.57%)
# [Tropical Dome 155/376] Dieffenbachia seguine - top1=Goeppertia makoyana (82.14%)
# [Tropical Dome 156/376] Dietes grandiflora variegata - top1=Dietes grandiflora variegata (99.92%) ✅
# [Tropical Dome 157/376] Dioon spinulosum - top1=Encephalartos horridus (45.62%)
# [Tropical Dome 158/376] Diospyros ebenum - top1=Murraya  paniculata (88.65%)
# [Tropical Dome 159/376] Diospyros nigra - top1=Psidium guajava (66.88%)
# [Tropical Dome 160/376] Disocactus anguliger - top1=Epiphyllum oxypetalum (22.16%)
# [Tropical Dome 161/376] Disocactus - top1=Billbergia nutans (98.24%)
# [Tropical Dome 162/376] Dracaena angolensis - top1=Beaucarnea recurvata (98.68%)
# [Tropical Dome 163/376] Dracaena fragrans - top1=Crescentia cujete (17.73%)
# [Tropical Dome 164/376] Dracaena marginata - top1=Dracaena reflexa (27.38%)
# [Tropical Dome 165/376] Dracaena reflexa - top1=Dracaena reflexa (27.38%) ✅
# [Tropical Dome 166/376] Dracaena surculosa - top1=Dracaena surculosa (96.07%) ✅
# [Tropical Dome 167/376] Duranta erecta - top1=Duranta erecta (99.43%) ✅
# [Tropical Dome 168/376] Elettaria cardamomum - top1=Hedychium coronarium (53.48%)
# [Tropical Dome 169/376] Encephalartos hildebrandtii - top1=Agave victoriae-reginae (62.57%)
# [Tropical Dome 170/376] Epiphyllum hookeri - top1=Cephalocereus senilis (49.44%)
# [Tropical Dome 171/376] Epiphyllum oxypetalum - top1=Cephalocereus senilis (46.83%)
# [Tropical Dome 172/376] Epipremnum aureum - top1=Epipremnum aureum (58.87%) ✅
# [Tropical Dome 173/376] Epipremnum pinnatum - top1=Amorphophallus titanum (65.24%)
# [Tropical Dome 174/376] Etlingera elatior - top1=Alocasia x mortfontanensis (59.45%)
# [Tropical Dome 175/376] Urceolina caucana - top1=Alpinia nutans (36.43%)
# [Tropical Dome 176/376] Eucomis comosa - top1=Colocasia esculenta 'Nancy's Revenge' (36.67%)
# [Tropical Dome 177/376] Eugenia uniflora - top1=Eugenia uniflora (79.16%) ✅
# [Tropical Dome 178/376] Ficus benghalensis - top1=Ficus benghalensis (52.55%) ✅
# [Tropical Dome 179/376] Ficus lutea - top1=Clerodendrum quadriloculare (56.06%)
# [Tropical Dome 180/376] Ficus lyrata - top1=Ficus benghalensis (74.98%)
# [Tropical Dome 181/376] Ficus montana - top1=Asclepias curassavica (17.57%)
# [Tropical Dome 182/376] Ficus pumila - top1=Ficus religiosa (98.59%)
# [Tropical Dome 183/376] Ficus religiosa - top1=Ficus religiosa (99.78%) ✅
# [Tropical Dome 184/376] Ficus villosa - top1=Davallia  fejeensis (45.14%)
# [Tropical Dome 185/376] Fittonia albivenis - top1=Anthurium clarinervium (96.44%)
# [Tropical Dome 186/376] Galphimia glauca - top1=Heteropterys laurifolia (56.72%)
# [Tropical Dome 187/376] Gardenia jasminoides - top1=Gardenia jasminoides (97.22%) ✅
# [Tropical Dome 188/376] Gloriosa superba - top1=Gloriosa superba 'Rothschildiana' (43.08%)
# [Tropical Dome 189/376] Gmelina arborea - top1=Gmelina arborea (99.30%) ✅
# [Tropical Dome 190/376] Gomphocarpus physocarpus - top1=Gomphocarpus physocarpus (100.00%) ✅
# [Tropical Dome 191/376] Gonatopus boivinii - no wiki image
# [Tropical Dome 192/376] Goudaea ospinae - top1=Neoregelia hybrid (27.18%)
# [Tropical Dome 193/376] Graptophyllum pictum - top1=Clerodendrum quadriloculare (67.42%)
# [Tropical Dome 194/376] Guzmania - top1=Guzmania (25.17%) ✅
# [Tropical Dome 195/376] Guzmania lingulata - top1=Vriesea imperialis green (67.28%)
# [Tropical Dome 196/376] Hamelia cuprea - top1=Hamelia patens (96.54%)
# [Tropical Dome 197/376] Hamelia patens - top1=Hamelia patens (97.93%) ✅
# [Tropical Dome 198/376] Hatiora salicornioides - top1=Thevetia ahouai (29.76%)
# [Tropical Dome 199/376] Hedychium - top1=Hedychium coronarium (99.97%)
# [Tropical Dome 200/376] Hedychium coccineum - top1=Guzmania (49.23%)
# [Tropical Dome 201/376] Hedychium coronarium - top1=Hedychium coronarium (99.54%) ✅
# [Tropical Dome 202/376] Hedychium flavum - top1=Hedychium coronarium (99.97%)
# [Tropical Dome 203/376] Heliconia latispatha - top1=Heliconia latispatha 'Orange Gyro' (93.50%)
# [Tropical Dome 204/376] Heliconia orthotricha - top1=Heliconia latispatha 'Orange Gyro' (93.50%)
# [Tropical Dome 205/376] Heliconia psittacorum - top1=Heliconia psittacorum x spathocircinata 'Orange Torch' (44.30%)
# [Tropical Dome 206/376] Heliconia rostrata - top1=Heliconia rostrata (95.37%) ✅
# [Tropical Dome 207/376] Heliconia stricta - top1=Heliconia rostrata (62.74%)
# [Tropical Dome 208/376] Heteropterys laurifolia - top1=Heteropterys laurifolia (78.93%) ✅
# [Tropical Dome 209/376] Hibiscus clayi - top1=Hibiscus clayi (56.13%) ✅
# [Tropical Dome 210/376] Hibiscus rosa-sinensis - top1=Hibiscus rosa-sinensis 'Snow Queen' (74.90%)
# [Tropical Dome 211/376] Hibiscus schizopetalus - top1=Hibiscus schizopetalus (95.17%) ✅
# [Tropical Dome 212/376] Hippeastrum - top1=Hippeastrum puniceum (97.23%)
# [Tropical Dome 213/376] Hohenbergia catingae - top1=Cordyline fruticosa 'Firebrand' (79.86%)
# [Tropical Dome 214/376] Hohenbergia lemei - top1=Guzmania (35.67%)
# [Tropical Dome 215/376] Hohenbergia rosea - top1=Guzmania (35.67%)
# [Tropical Dome 216/376] Homalocladium platycladum - top1=Dracaena draco (17.94%)
# [Tropical Dome 217/376] Hoya carnosa - top1=Hoya carnosa 'Variegata' (94.07%)
# [Tropical Dome 218/376] Pombalia communis - top1=Justicia brandegeeana 'Mutant' (62.57%)
# [Tropical Dome 219/376] Pombalia prunifolia - top1=Justicia brandegeeana 'Mutant' (62.57%)
# [Tropical Dome 220/376] Selenicereus undatus - top1=Hylocereus undatus (77.37%)
# [Tropical Dome 221/376] Hymenocallis caribaea - top1=Crinum asiaticum (93.59%)
# [Tropical Dome 222/376] Ilex paraguariensis - top1=Thevetia ahouai (93.28%)
# [Tropical Dome 223/376] Impatiens DMR - top1=Bauhinia purpurea (42.29%)
# [Tropical Dome 224/376] Jatropha integerrima - top1=Asclepias curassavica (55.10%)
# [Tropical Dome 225/376] Justicia brandegeeana - top1=Justicia brandegeeana 'Fruit Cocktail' (72.51%)
# [Tropical Dome 226/376] Justicia carnea - top1=Justicia carnea (92.18%) ✅
# [Tropical Dome 227/376] Justicia floribunda - top1=Justicia floribunda (59.93%) ✅
# [Tropical Dome 228/376] Kaempferia pulchra - top1=Kaempferia pulchra (70.79%) ✅
# [Tropical Dome 229/376] Kerriodoxa elegans - top1=Neoregelia (31.55%)
# [Tropical Dome 230/376] Kigelia africana - top1=Kigelia africana (99.67%) ✅
# [Tropical Dome 231/376] Leea guineensis - top1=Begonia 'Elaine' (69.69%)
# [Tropical Dome 232/376] Livistona chinensis - top1=Yucca aloifolia (?) (22.07%)
# [Tropical Dome 233/376] Macadamia integrifolia - top1=Polyscias guilfoylei 'Ming Gold' (39.14%)
# [Tropical Dome 234/376] Magnolia figo - top1=Magnolia figo (85.38%) ✅
# [Tropical Dome 235/376] Malpighia glabra - top1=Adenia sp. (51.98%)
# [Tropical Dome 236/376] Manilkara zapota - top1=Couroupita guianensis (76.30%)
# [Tropical Dome 237/376] Mansoa alliacea - top1=Mansoa alliacea (80.03%) ✅
# [Tropical Dome 238/376] Marcgravia rectiflora - top1=Costus woodsonii (76.24%)
# [Tropical Dome 239/376] Marcgravia - top1=Marcgravia sp. (60.01%)
# [Tropical Dome 240/376] Medinilla magnifica - top1=Medinilla magnifica (45.55%) ✅
# [Tropical Dome 241/376] Megaskepasma erythrochlamys - top1=Acalypha hispida (93.61%)
# [Tropical Dome 242/376] Microsorum musifolium - top1=Asplenium nidus (95.41%)
# [Tropical Dome 243/376] Microsorum punctatum - top1=Asplenium nidus (95.41%)
# [Tropical Dome 244/376] Mimosa pudica - top1=Mimosa pudica (72.75%) ✅
# [Tropical Dome 245/376] Molineria capitulata - top1=Dracaena draco (47.79%)
# [Tropical Dome 246/376] Monstera deliciosa - top1=Monstera deliciosa (91.17%) ✅
# [Tropical Dome 247/376] Monstera obliqua - top1=Syngonium podophyllum (25.69%)
# [Tropical Dome 248/376] Moringa oleifera - top1=Moringa oleifera (80.61%) ✅
# [Tropical Dome 249/376] Murraya paniculata - top1=Murraya  paniculata (99.34%)
# [Tropical Dome 250/376] Musa - no wiki image
# [Tropical Dome 251/376] Musa acuminata - top1=Goeppertia makoyana (68.87%)
# [Tropical Dome 252/376] Nematanthus - top1=Eugenia uniflora (55.72%)
# [Tropical Dome 253/376] Neomarica gracilis - top1=Cordyline fruticosa 'Harlequin' (96.43%)
# [Tropical Dome 254/376] Neoregelia - top1=Neoregelia (30.66%) ✅
# [Tropical Dome 255/376] Neoregelia carolinae - top1=Neoregelia carolinae (76.06%) ✅
# [Tropical Dome 256/376] Neoregelia hybrid - top1=Neoregelia (30.66%)
# [Tropical Dome 257/376] Nephrolepis exaltata - top1=Nephrolepis exaltata (99.50%) ✅
# [Tropical Dome 258/376] Nerium oleander - top1=Nerium oleander (96.35%) ✅
# [Tropical Dome 259/376] Odontonema callistachyum - top1=Pseuderanthemum carruthersii var. atropurpureum (41.63%)
# [Tropical Dome 260/376] Oncidium sphacelatum - top1=Oncidium sphacelatum (70.42%) ✅
# [Tropical Dome 261/376] Oxalis - top1=Polyscias balfouriana (99.74%)
# [Tropical Dome 262/376] Pachira sessilis - top1=Philodendron billietiae (83.59%)
# [Tropical Dome 263/376] Pachystachys coccinea - top1=Aeschynanthus pulcher (45.39%)
# [Tropical Dome 264/376] Pachystachys lutea - top1=Pachystachys lutea (86.83%) ✅
# [Tropical Dome 265/376] Pandanus tectorius - top1=Pandanus tectorius 'Variegata' (37.83%)
# [Tropical Dome 266/376] Passiflora caerulea - top1=Passiflora caerulea 'Blue Bahama' (81.44%)
# [Tropical Dome 267/376] Passiflora x - top1=Azadirachta indica (53.45%)
# [Tropical Dome 268/376] Pavonia - no wiki image
# [Tropical Dome 269/376] Peperomia obtusifolia - top1=Peperomia obtusifolia (99.20%) ✅
# [Tropical Dome 270/376] Peperomia prostrata - top1=Peperomia prostrata (73.10%) ✅
# [Tropical Dome 271/376] Peperomia rotundifolia - top1=Peperomia obtusifolia (96.71%)
# [Tropical Dome 272/376] Petraeovitex bambusetorum - top1=Justicia floribunda (50.92%)
# [Tropical Dome 273/376] Philodendron - top1=Alocasia macrorrhizos 'Black Stem' (22.64%)
# [Tropical Dome 274/376] Philodendron billietiae - top1=Philodendron billietiae (85.34%) ✅
# [Tropical Dome 275/376] Philodendron bipinnatifidum - top1=Philodendron bipinnatifidum (87.97%) ✅
# [Tropical Dome 276/376] Philodendron burle-marxii - top1=Monstera obliqua (46.40%)
# [Tropical Dome 277/376] Philodendron copense - top1=Alocasia macrorrhizos 'Black Stem' (22.64%)
# [Tropical Dome 278/376] Philodendron gloriosum - top1=Philodendron gloriosum (70.94%) ✅
# [Tropical Dome 279/376] Philodendron hastatum - top1=Philodendron hastatum (32.14%) ✅
# [Tropical Dome 280/376] Philodendron martianum - top1=Alpinia purpurata 'Pink Ginger' (61.04%)
# [Tropical Dome 281/376] Philodendron melanochrysum - top1=Philodendron melanochrysum (33.86%) ✅
# [Tropical Dome 282/376] Philodendron pastazanum - top1=Philodendron pastazanum (99.41%) ✅
# [Tropical Dome 283/376] Philodendron pinnatifidum - top1=Monstera deliciosa (78.14%)
# [Tropical Dome 284/376] Philodendron plowmanii - top1=Alocasia macrorrhizos 'Black Stem' (22.64%)
# [Tropical Dome 285/376] Philodendron selloum - top1=Philodendron bipinnatifidum (87.97%)
# [Tropical Dome 286/376] Philodendron warscewiczii - top1=Alocasia macrorrhizos 'Black Stem' (22.64%)
# [Tropical Dome 287/376] Philodendron x - top1=Alocasia macrorrhizos 'Black Stem' (22.64%)
# [Tropical Dome 288/376] Phlebodium aureum - top1=Pteris ensiformis 'Evergemiensis' (59.57%)
# [Tropical Dome 289/376] Phoenix canariensis - top1=Phoenix canariensis (99.83%) ✅
# [Tropical Dome 290/376] Phoenix roebelenii - top1=Phoenix roebelenii (98.01%) ✅
# [Tropical Dome 291/376] Phymatosorus diversifolius - top1=Codiaeum variegatum 'Oakleaf' (31.82%)
# [Tropical Dome 292/376] Pilea cadierei - top1=Aspidistra elatior 'Asahi' (74.56%)
# [Tropical Dome 293/376] Pilea depressa - top1=PORTULACARIA AFRA (68.82%)
# [Tropical Dome 294/376] Pilea peperomioides - top1=Vanilla planifolia (28.01%)
# [Tropical Dome 295/376] Pimenta dioica - top1=Macadamia integrifolia (38.69%)
# [Tropical Dome 296/376] Piper chaba - top1=Piper nigrum (92.28%)
# [Tropical Dome 297/376] Piper crocatum - no wiki image
# [Tropical Dome 298/376] Piper methysticum - top1=Piper nigrum (68.29%)
# [Tropical Dome 299/376] Piper nigrum - top1=Piper nigrum (94.24%) ✅
# [Tropical Dome 300/376] Piper unguiculatum - no wiki image
# [Tropical Dome 301/376] Platycerium alcicorne - top1=Platycerium alcicorne (99.27%) ✅
# [Tropical Dome 302/376] Pleiostachya pruinosa - top1=Goeppertia ornata 'Rosea-lineata' (76.75%)
# [Tropical Dome 303/376] Plinia cauliflora - top1=Kigelia africana (45.14%)
# [Tropical Dome 304/376] Plumbago auriculata - top1=Plumbago auriculata (100.00%) ✅
# [Tropical Dome 305/376] Plumeria rubra - top1=Aphelandra sinclairiana (95.44%)
# [Tropical Dome 306/376] Polypodium formosanum - top1=Polypodium 'Green Wave' (98.25%)
# [Tropical Dome 307/376] Polypodium - top1=Cyrtomium falcatum (82.68%)
# [Tropical Dome 308/376] Polyscias balfouriana - top1=Begonia 'Elaine' (56.26%)
# [Tropical Dome 309/376] Polyscias guilfoylei - top1=Nephrolepis exaltata (92.06%)
# [Tropical Dome 310/376] Porphyrocoma pohliana - top1=Justicia carnea (90.11%)
# [Tropical Dome 311/376] Portea - top1=Aechmea gamosepala (61.46%)
# [Tropical Dome 312/376] Portea petropolitana - top1=Aechmea gamosepala (39.18%)
# [Tropical Dome 313/376] Pseuderanthemum alatum - top1=Pseuderanthemum carruthersii var. atropurpureum 'Black Varnish' (29.85%)
# [Tropical Dome 314/376] Pseuderanthemum carruthersii - top1=Justicia brandegeeana 'Fruit Cocktail' (76.38%)
# [Tropical Dome 315/376] Pseuderanthemum laxiflorum - top1=Pseuderanthemum laxiflorum (97.70%) ✅
# [Tropical Dome 316/376] Pseuderanthemum variabile - top1=Pseuderanthemum variabile (93.06%) ✅
# [Tropical Dome 317/376] Psidium cattleianum - top1=Psidium sp. (86.63%)
# [Tropical Dome 318/376] Psidium guajava - top1=Citrus medica (67.41%)
# [Tropical Dome 319/376] Psidium - top1=Psidium guajava (96.55%)
# [Tropical Dome 320/376] Psilotum nudum - top1=Psilotum nudum (96.69%) ✅
# [Tropical Dome 321/376] Pteris cretica - top1=Pteris cretica 'Albolineata' (92.84%)
# [Tropical Dome 322/376] Pteris ensiformis - top1=Epipremnum pinnatum 'Marble Planet' (43.54%)
# [Tropical Dome 323/376] Pyrrosia lingua - top1=Anthurium hybrid (40.72%)
# [Tropical Dome 324/376] Quesnelia marmorata - top1=Neoregelia carolinae (35.91%)
# [Tropical Dome 325/376] Rhaphidophora tetrasperma - top1=Vanilla planifolia 'Variegata' (48.45%)
# [Tropical Dome 326/376] Rhapis excelsa - top1=Rhapis excelsa (49.13%) ✅
# [Tropical Dome 327/376] Rhipsalis pilocarpa - top1=Rhipsalis pilocarpa (92.66%) ✅
# [Tropical Dome 328/376] Rhipsalis - top1=Swietenia macrophylla (37.73%)
# [Tropical Dome 329/376] Rhoeo spathacea - top1=Dracaena draco (54.44%)
# [Tropical Dome 330/376] Ruellia affinis - top1=Ruellia affinis (78.87%) ✅
# [Tropical Dome 331/376] Ruellia amoena - top1=Ruellia elegans (26.94%)
# [Tropical Dome 332/376] Ruellia elegans - top1=Barleria repens 'Rosea' (49.98%)
# [Tropical Dome 333/376] Ruellia prostrata - top1=Ruellia prostrata (47.03%) ✅
# [Tropical Dome 334/376] Ruellia simplex - top1=Ruellia simplex (50.41%) ✅
# [Tropical Dome 335/376] Ruscus aculeatus - top1=Zingiber zerumbet (31.39%)
# [Tropical Dome 336/376] Ruspolia hypocrateriformis - top1=Ruspolia hypocrateriformis (29.49%) ✅
# [Tropical Dome 337/376] Ruttya fruticosa - top1=Aeschynanthus pulcher (84.04%)
# [Tropical Dome 338/376] Saccharum officinarum - top1=Neoregelia (22.83%)
# [Tropical Dome 339/376] Sanchezia nobilis - top1=Heliconia rostrata (54.34%)
# [Tropical Dome 340/376] Saribus rotundifolius - top1=Dracaena marginata (27.46%)
# [Tropical Dome 341/376] Sauromatum venosum - top1=Monstera deliciosa (70.72%)
# [Tropical Dome 342/376] Plerandra elegantissima - top1=Euphorbia grandidens (83.68%)
# [Tropical Dome 343/376] Scindapsus pictus - top1=Dracaena trifasciata (33.72%)
# [Tropical Dome 344/376] Selaginella moellendorffii - top1=Selaginella moellendorffii (94.15%) ✅
# [Tropical Dome 345/376] Selenicereus anthonyanus - top1=Cleistocactus sp. (30.84%)
# [Tropical Dome 346/376] Spathiphyllum wallisii - top1=Anthurium andraeanum (78.50%)
# [Tropical Dome 347/376] Stenochlaena palustris - top1=Nephrolepis exaltata (99.31%)
# [Tropical Dome 348/376] Strelitzia nicolai - top1=Strelitzia nicolai (95.03%) ✅
# [Tropical Dome 349/376] Stromanthe thalia - top1=Graptophyllum pictum 'Chocolate' (59.25%)
# [Tropical Dome 350/376] Swietenia macrophylla - top1=Swietenia macrophylla (91.38%) ✅
# [Tropical Dome 351/376] Swietenia mahagoni - top1=Tamarindus indica (92.98%)
# [Tropical Dome 352/376] Syngonium podophyllum - top1=Syngonium podophyllum (51.53%) ✅
# [Tropical Dome 353/376] Tabernaemontana divaricata - top1=Tabernaemontana divaricata (53.04%) ✅
# [Tropical Dome 354/376] Tamarindus indica - top1=Tamarindus indica (92.64%) ✅
# [Tropical Dome 355/376] Tapeinochilos ananassae - top1=Dichorisandra thyrsiflora 'Pendant' (33.03%)
# [Tropical Dome 356/376] Tecoma capensis - top1=Tecoma capensis (81.62%) ✅
# [Tropical Dome 357/376] Tecomanthe dendrophila - top1=Anthurium andraeanum (54.11%)
# [Tropical Dome 358/376] Thaumatophyllum xanadu - top1=Philodendron bipinnatifidum (51.99%)
# [Tropical Dome 359/376] Theobroma cacao - top1=Theobroma cacao (100.00%) ✅
# [Tropical Dome 360/376] Thevetia ahouai - top1=Euphorbia unknown hybrid (33.20%)
# [Tropical Dome 361/376] Thunbergia erecta - top1=Thunbergia erecta (99.97%) ✅
# [Tropical Dome 362/376] Thunbergia mysorensis - top1=Thunbergia mysorensis (96.93%) ✅
# [Tropical Dome 363/376] Wallisia cyanea - top1=Rhipsalis sp. (70.30%)
# [Tropical Dome 364/376] Tillandsia xerographica - top1=Aechmea chantinii (75.67%)
# [Tropical Dome 365/376] Typhonodorum lindleyanum - top1=Asplenium nidus (64.41%)
# [Tropical Dome 366/376] Vanilla planifolia - top1=Aspidistra elatior 'Variegata' (66.83%)
# [Tropical Dome 367/376] Vriesea - top1=Vriesea simplex x mariae (59.16%)
# [Tropical Dome 368/376] Vriesea imperialis green - top1=Vriesea simplex x mariae (59.16%)
# [Tropical Dome 369/376] Vriesea simplex - top1=Vriesea simplex x mariae (59.16%)
# [Tropical Dome 370/376] Vriesea splendens - top1=Adiantum peruvianum (51.32%)
# [Tropical Dome 371/376] Xanthosoma sagittifolium - top1=Epipremnum pinnatum 'Marble Planet' (34.08%)
# [Tropical Dome 372/376] Zamia furfuraceae - top1=Alluaudia COMOSA (71.51%)
# [Tropical Dome 373/376] Zamioculcas zamiifolia - top1=Peperomia obtusifolia 'Marble' (89.14%)
# [Tropical Dome 374/376] Zapoteca portoricensis - no wiki image
# [Tropical Dome 375/376] Zingiber officianale - top1=Aspidistra elatior 'Variegata' (75.12%)
# [Tropical Dome 376/376] Zingiber zerumbet - top1=Hedychium coronarium (78.78%)
#
# ============================================================
# Evaluating dome: Desert Dome (348 species)
# ============================================================
# [Desert Dome 1/348] Adromischus - top1=Crassula ovata (53.38%)
# [Desert Dome 2/348] Agave angustifolia - top1=Agave angustifolia (77.83%) ✅
# [Desert Dome 3/348] Agave schottii - top1=Agave lechuguilla (86.95%)
# [Desert Dome 4/348] Agave stricta - top1=Yucca elata (71.48%)
# [Desert Dome 5/348] Aloe - top1=Aloe vaombe (36.04%)
# [Desert Dome 6/348] Cereus - no wiki image
# [Desert Dome 7/348] Crassula lactea - top1=Crassula ovata (73.39%)
# [Desert Dome 8/348] Drimiopsis maculata - top1=Aechmea gamosepala (28.69%)
# [Desert Dome 9/348] Euphorbia abyssinica - top1=Euphorbia abyssinica (99.97%) ✅
# [Desert Dome 10/348] Euphorbia - top1=Adenia sp. (53.10%)
# [Desert Dome 11/348] Ferocactus emoryi - top1=Ferocactus wislizeni (98.61%)
# [Desert Dome 12/348] Ferocactus - top1=Ferocactus hystrix (97.96%)
# [Desert Dome 13/348] Fouquieria formosa - top1=Fouquieria formosa (80.93%) ✅
# [Desert Dome 14/348] Gasteraloe - top1=Gasteria species (39.66%)
# [Desert Dome 15/348] Gasteria hybrid - top1=Gasteria species (48.47%)
# [Desert Dome 16/348] Gasteria - top1=Gasteria species (48.47%)
# [Desert Dome 17/348] Gasteria species - top1=Gasteria species (48.47%) ✅
# [Desert Dome 18/348] Gasterworthia - no wiki image
# [Desert Dome 19/348] Graptopetalum - top1=Graptopetalum amethystinum (73.96%)
# [Desert Dome 20/348] Graptoveria #2(?) - no wiki image
# [Desert Dome 21/348] Graptoveria #3(?) - no wiki image
# [Desert Dome 22/348] Gymnocalycium possibly saglione - top1=Gymnocalycium unknown (13.20%)
# [Desert Dome 23/348] Gymnocalycium - top1=Gymnocalycium unknown (13.20%)
# [Desert Dome 24/348] Haworthia - top1=Haworthia cymbiformis (49.90%)
# [Desert Dome 25/348] Haworthiopsis attenuata - top1=Mammillaria sp. (8.33%)
# [Desert Dome 26/348] Hectia argentea - no wiki image
# [Desert Dome 27/348] Hectia - no wiki image
# [Desert Dome 28/348] Juttadinteria suavissima - top1=Crassula lactea (40.24%)
# [Desert Dome 29/348] Mammillaria - top1=Mammillaria parkinsonii (38.30%)
# [Desert Dome 30/348] Opuntia - top1=Opuntia robusta (42.41%)
# [Desert Dome 31/348] Raphianacme flanaganii - no wiki image
# [Desert Dome 32/348] Sedum pachyphyllum - top1=Adenia sp. (59.18%)
# [Desert Dome 33/348] Senecio crassisimus - top1=Senecio crassisimus (30.94%) ✅
# [Desert Dome 34/348] Unknown - no wiki image
# [Desert Dome 35/348] Yucca aloifolia (?) - top1=Yucca rostrata (51.84%)
# [Desert Dome 36/348] Adenium boehmianum - top1=Hibiscus rosa-sinensis 'Erin Rachael' (49.48%)
# [Desert Dome 37/348] Aloe cameronii - top1=Aloe arborescens (28.35%)
# [Desert Dome 38/348] Aloe excelsa - top1=Aloe sp. (20.23%)
# [Desert Dome 39/348] Aloe harlana - top1=Aloe maculata (42.14%)
# [Desert Dome 40/348] Aloe jacksonii - top1=Aloe vaombe (36.04%)
# [Desert Dome 41/348] Aloe jucunda - top1=Aloe jucunda (68.65%) ✅
# [Desert Dome 42/348] Aloe maculata - top1=Aloe sp. (21.45%)
# [Desert Dome 43/348] Aloe munchii - top1=Aloe vaombe (36.04%)
# [Desert Dome 44/348] Aloe perfoliata - top1=Aloe jacksonii (53.44%)
# [Desert Dome 45/348] Aloe rivae - top1=Aloe vaombe (36.04%)
# [Desert Dome 46/348] Aloe rivierei - top1=Aloe vaombe (36.04%)
# [Desert Dome 47/348] Aloidendron barberae - top1=Aloe unknown (16.93%)
# [Desert Dome 48/348] Ceropegia woodii - top1=Anthurium clarinervium (44.98%)
# [Desert Dome 49/348] Cotyledon tomentosa - top1=Crassula ovata (28.05%)
# [Desert Dome 50/348] Dracaena angolensis - top1=Beaucarnea recurvata (98.68%)
# [Desert Dome 51/348] Dracaena serpenta - no wiki image
# [Desert Dome 52/348] Dracaena trifasciata - top1=Zingiber zerumbet (26.45%)
# [Desert Dome 53/348] Dracaena - no wiki image
# [Desert Dome 54/348] Euphorbia lactea cristata - top1=Adenia sp. (53.10%)
# [Desert Dome 55/348] Euphorbia tirucalli - top1=Euphorbia tirucalli (99.71%) ✅
# [Desert Dome 56/348] Gasteria obliqua - top1=Leuchtenbergia principis (19.67%)
# [Desert Dome 57/348] Dracaena canaliculata - no wiki image
# [Desert Dome 58/348] Aloe vera - top1=Aloe sp. (31.18%)
# [Desert Dome 59/348] Dasylirion wheeleri - top1=Dasylirion wheeleri (40.09%) ✅
# [Desert Dome 60/348] Tephrocactus articulatus - top1=MYRTILLOCACTUS  GEOMETRIZANS (95.15%)
# [Desert Dome 61/348] STETSONIA CORYNE - no wiki image
# [Desert Dome 62/348] Agave toumeyana - top1=Agave lechuguilla (47.80%)
# [Desert Dome 63/348] Carnegiea gigantea - top1=Carnegiea gigantea (97.71%) ✅
# [Desert Dome 64/348] Yucca elata - top1=Yucca elata (97.65%) ✅
# [Desert Dome 65/348] Brachychiton rupestris - top1=Brachychiton rupestris (99.18%) ✅
# [Desert Dome 66/348] Brachychiton - top1=Brachychiton sp. (40.63%)
# [Desert Dome 67/348] Cassia artemisioides - top1=Larrea tridentata (99.97%)
# [Desert Dome 68/348] Eremophila glabra - top1=Justicia floribunda (91.47%)
# [Desert Dome 69/348] Maireana sedifolia - top1=Maireana sedifolia (43.99%) ✅
# [Desert Dome 70/348] Brahea armata - top1=Dracaena pethera (18.85%)
# [Desert Dome 71/348] Fouquieria columnaris - top1=Fouquieria columnaris (99.87%) ✅
# [Desert Dome 72/348] Cleistocactus winteri - top1=Cleistocactus samaipatanus (48.96%)
# [Desert Dome 73/348] OREOCEREUS CELsIANUS - no wiki image
# [Desert Dome 74/348] Hohenbergia magnispina - top1=Guzmania (35.67%)
# [Desert Dome 75/348] Aeonium - top1=Aeonium 'Kiwi' (54.73%)
# [Desert Dome 76/348] Aeonium hybrid - top1=Aeonium 'Kiwi' (54.73%)
# [Desert Dome 77/348] Aeonium lindleyi - top1=Aeonium 'Kiwi' (54.73%)
# [Desert Dome 78/348] Aeonium simsii - top1=Aeonium 'Kiwi' (54.73%)
# [Desert Dome 79/348] Aeonium species - top1=Aeonium 'Kiwi' (54.73%)
# [Desert Dome 80/348] Dracaena draco - top1=Dracaena draco (98.04%) ✅
# [Desert Dome 81/348] Aloe deltoideodonta - top1=Aloe microstigma (40.99%)
# [Desert Dome 82/348] Kalanchoe tomentosa - top1=Kalanchoe  tomentosa (98.33%)
# [Desert Dome 83/348] Calibanus hookeri - top1=Euphorbia antisyphilitica (72.78%)
# [Desert Dome 84/348] Cephalocereus senilis - top1=Fouquieria columnaris (55.08%)
# [Desert Dome 85/348] Echinocactus grusonii - top1=Ferocactus hystrix (73.89%)
# [Desert Dome 86/348] Stenocereus pruinosus - top1=Stenocereus pruinosus (50.67%) ✅
# [Desert Dome 87/348] Copiapoa gigantea - top1=Carnegiea gigantea (32.72%)
# [Desert Dome 88/348] Dracaena ballyi - top1=Kalanchoe beauverdii (38.61%)
# [Desert Dome 89/348] Agave - top1=Aloe vera (81.15%)
# [Desert Dome 90/348] Agave americana - top1=Agave parrasana (54.06%)
# [Desert Dome 91/348] Aloe arborescens - top1=Aloe sp. (26.97%)
# [Desert Dome 92/348] Dracaena pethera - top1=Aloe vera (13.72%)
# [Desert Dome 93/348] Gasteria batesiana - top1=Gasteria sp (18.47%)
# [Desert Dome 94/348] Nopalea cochenillifera - top1=Opuntia robusta (42.41%)
# [Desert Dome 95/348] Opuntia ellisiana - top1=Opuntia robusta (42.41%)
# [Desert Dome 96/348] Salvia microphylla - top1=Clerodendrum thomsoniae (49.85%)
# [Desert Dome 97/348] Agave filifera - top1=Agave stricta (66.58%)
# [Desert Dome 98/348] FEROCACTUS GLAUCESCENS - no wiki image
# [Desert Dome 99/348] Pilosocereus palmeri - top1=Euphorbia horrida 'Snowflake' (27.08%)
# [Desert Dome 100/348] Cereus repandus - top1=Pachycereus sp. (30.90%)
# [Desert Dome 101/348] Opuntia echios - top1=Kalanchoe beharensis (74.88%)
# [Desert Dome 102/348] Opuntia galapageia - top1=Kalanchoe beharensis (74.88%)
# [Desert Dome 103/348] Sedum dendroideum - top1=Aeonium lindleyi (67.36%)
# [Desert Dome 104/348] Agave eggersiana - top1=Agave eggersiana (64.10%) ✅
# [Desert Dome 105/348] Aloe juvenna - top1=Aloe rauhii (67.74%)
# [Desert Dome 106/348] Euphorbia buruana - top1=Adenia sp. (53.10%)
# [Desert Dome 107/348] Adenia - top1=Kleinia madagascariensis (53.66%)
# [Desert Dome 108/348] Adenia SPECIES # 2 - top1=Kleinia madagascariensis (53.66%)
# [Desert Dome 109/348] Allauadia procera - no wiki image
# [Desert Dome 110/348] Alluaudia ascendens - top1=Agave victoriae-reginae (76.08%)
# [Desert Dome 111/348] Aloe acutissima - top1=Aloe vaombe (36.04%)
# [Desert Dome 112/348] Aloe conifera - top1=Aloe vaombe (36.04%)
# [Desert Dome 113/348] Aloe erythrophylla - top1=Agave stricta 'Nana' (49.79%)
# [Desert Dome 114/348] Aloe rauhii - top1=Leuchtenbergia principis (87.03%)
# [Desert Dome 115/348] Aloe suarezensis - top1=Aloe vaombe (36.04%)
# [Desert Dome 116/348] Aloe vaombe - top1=Beaucarnea recurvata (32.60%)
# [Desert Dome 117/348] Aloe vaotsanda - top1=Aloe vaombe (36.04%)
# [Desert Dome 118/348] Bismarkia nobilis - top1=Nolina lindheimeriana (48.28%)
# [Desert Dome 119/348] Catharanthus roseus - top1=Catharanthus roseus (99.98%) ✅
# [Desert Dome 120/348] Commiphora monstruosa - top1=Vanilla planifolia (50.95%)
# [Desert Dome 121/348] Didierea trollii - top1=Euphorbia beharensis ? (97.56%)
# [Desert Dome 122/348] Didieria madagascariensis - no wiki image
# [Desert Dome 123/348] Euphorbia aff croizatii - top1=Adenia sp. (53.10%)
# [Desert Dome 124/348] Euphorbia betrokana - top1=Adenia sp. (53.10%)
# [Desert Dome 125/348] Euphorbia capsaintemariensis - top1=Euphorbia stenoclada (90.53%)
# [Desert Dome 126/348] Euphorbia croizatii - top1=Euphorbia sakarahaensis (49.91%)
# [Desert Dome 127/348] Euphorbia decaryi - top1=PORTULACARIA AFRA (45.51%)
# [Desert Dome 128/348] Euphorbia duranii - top1=Euphorbia duranii (26.22%) ✅
# [Desert Dome 129/348] Euphorbia enterophora - top1=Euphorbia tirucalli (80.61%)
# [Desert Dome 130/348] Euphorbia francoisii - top1=Euphorbia decaryi (18.10%)
# [Desert Dome 131/348] Euphorbia genoudiana - top1=Adenia sp. (53.10%)
# [Desert Dome 132/348] Euphorbia hedyotoides - top1=Euphorbia lophogona (90.99%)
# [Desert Dome 133/348] Euphorbia leandriana - top1=Adenia sp. (53.10%)
# [Desert Dome 134/348] Euphorbia lophogona - top1=Euphorbia lophogona (42.16%) ✅
# [Desert Dome 135/348] Euphorbia millii - top1=Adenia sp. (53.10%)
# [Desert Dome 136/348] Euphorbia neohumbertii - top1=Euphorbia decaryi var. spirosticha (39.07%)
# [Desert Dome 137/348] Euphorbia platyclada - top1=Euphorbia platyclada (38.80%) ✅
# [Desert Dome 138/348] Euphorbia sakarahaensis - top1=Beaucarnea recurvata (28.91%)
# [Desert Dome 139/348] Euphorbia stenoclada - top1=Euphorbia beharensis ? (70.21%)
# [Desert Dome 140/348] Euphorbia viguieri - top1=Adenia sp. (53.10%)
# [Desert Dome 141/348] Cynanchum grandidieri - top1=Hylocereus undatus (52.70%)
# [Desert Dome 142/348] Kalanchoe arborescens - top1=Kalanchoe bracteata (43.82%)
# [Desert Dome 143/348] Kalanchoe be-harotii - top1=PORTULACARIA AFRA (49.39%)
# [Desert Dome 144/348] Kalanchoe beauverdii - top1=Euphorbia tirucalli (68.33%)
# [Desert Dome 145/348] Kalanchoe beharensis - top1=Kalanchoe beharensis (98.25%) ✅
# [Desert Dome 146/348] Kalanchoe bracteata - top1=PORTULACARIA AFRA (49.39%)
# [Desert Dome 147/348] Kalanchoe delagoensis - top1=Kalanchoe delagoensis (57.39%) ✅
# [Desert Dome 148/348] Kalanchoe dinklagei - top1=PORTULACARIA AFRA (49.39%)
# [Desert Dome 149/348] Kalanchoe fedtschenkoi - top1=Kalanchoe fedtschenkoi (99.84%) ✅
# [Desert Dome 150/348] Kalanchoe hildebrandtii - top1=PORTULACARIA AFRA (49.39%)
# [Desert Dome 151/348] Kalanchoe millotii - top1=Kalanchoe millotii (95.21%) ✅
# [Desert Dome 152/348] Kalanchoe orgyalis - top1=Kalanchoe orgyalis (70.16%) ✅
# [Desert Dome 153/348] Kalanchoe rhombopilosa - top1=Kalanchoe rhombopilosa (100.00%) ✅
# [Desert Dome 154/348] Kalanchoe synsepela - top1=PORTULACARIA AFRA (49.39%)
# [Desert Dome 155/348] Kalanchoe viguieri - top1=PORTULACARIA AFRA (49.39%)
# [Desert Dome 156/348] Kleinia madagascariensis - top1=Aloe unknown (15.17%)
# [Desert Dome 157/348] Moringa hildebrantii - no wiki image
# [Desert Dome 158/348] OPERCULicARyA dECARYI - no wiki image
# [Desert Dome 159/348] Pachypodium gaeyi - top1=Aloe vera (30.65%)
# [Desert Dome 160/348] Pachypodium lamerei - top1=Plumeria rubra (77.97%)
# [Desert Dome 161/348] Pachypodium rosulatum - top1=Pachypodium rosulatum (55.79%) ✅
# [Desert Dome 162/348] Senecio crassissimus - top1=Senecio crassissimus (62.62%) ✅
# [Desert Dome 163/348] SENECIO DESCOINGSII - no wiki image
# [Desert Dome 164/348] Senna meridionalis - no wiki image
# [Desert Dome 165/348] SeYRIGIA bOSSERI - no wiki image
# [Desert Dome 166/348] SeYRIGIA - no wiki image
# [Desert Dome 167/348] TROCHOMERIOPSIS DIVERSIFOLIA - no wiki image
# [Desert Dome 168/348] Uncarina grandidieri - top1=Ficus lutea (73.31%)
# [Desert Dome 169/348] Xerosicyos danguyi - top1=Vanilla planifolia (36.58%)
# [Desert Dome 170/348] XEROSICYOS PERRIERI - no wiki image
# [Desert Dome 171/348] Zygosicyos pubescens - no wiki image
# [Desert Dome 172/348] Euphorbia mahafalensis - top1=Euphorbia decaryi (28.63%)
# [Desert Dome 173/348] Chamaerops humilis - top1=Chamaerops humilis (96.45%) ✅
# [Desert Dome 174/348] Agave albopilosa - top1=Aloe vera (81.15%)
# [Desert Dome 175/348] Agave attenuata - top1=Euphorbia abyssinica (26.25%)
# [Desert Dome 176/348] Agave attenuata variegata - top1=Aloe vera (81.15%)
# [Desert Dome 177/348] Agave bovicornuta - top1=Agave albopilosa (55.69%)
# [Desert Dome 178/348] Agave bracteosa - top1=Dracaena draco (20.56%)
# [Desert Dome 179/348] Agave geminiflora - top1=Yucca aloifolia (?) (73.17%)
# [Desert Dome 180/348] Agave mitis - top1=Agave 'Blue Glow' (54.68%)
# [Desert Dome 181/348] Agave parryi - top1=Agave albopilosa (92.77%)
# [Desert Dome 182/348] Agave polianthiflora - top1=Haworthia sp. (41.69%)
# [Desert Dome 183/348] Agave potatorum - top1=Kalanchoe beharensis (36.09%)
# [Desert Dome 184/348] Agave tequilana - top1=Agave bracteosa (71.06%)
# [Desert Dome 185/348] Agave titanota - top1=Agave tequilana (71.03%)
# [Desert Dome 186/348] Agave victoriae-reginae - top1=Agave victoriae-reginae (99.87%) ✅
# [Desert Dome 187/348] Astrophytum myriostigma - top1=Lithops hookeri (54.30%)
# [Desert Dome 188/348] Astrophytum ornatum - top1=Astrophytum ornatum (99.70%) ✅
# [Desert Dome 189/348] Beaucarnea recurvata - top1=Beaucarnea recurvata (99.90%) ✅
# [Desert Dome 190/348] Beiselia mexicana - top1=Bursera hindsiana (90.23%)
# [Desert Dome 191/348] Bursera fagaroides - top1=Bulnesia arborea (45.62%)
# [Desert Dome 192/348] Bursera odorata - top1=Bulnesia arborea (45.62%)
# [Desert Dome 193/348] Echeveria - top1=PACHYPHYTUM BRACTEOSUM (28.58%)
# [Desert Dome 194/348] Echeveria carnicolor - top1=PACHYPHYTUM BRACTEOSUM (75.35%)
# [Desert Dome 195/348] Echeveria multicaulis - top1=Echeveria multicaulis (64.83%) ✅
# [Desert Dome 196/348] Echinocereus brandegeei - top1=Cleistocactus sp. (42.11%)
# [Desert Dome 197/348] Echinocereus pentalophus - top1=Echinocereus pentalophus (99.46%) ✅
# [Desert Dome 198/348] Euphorbia lomelii - top1=Euphorbia antisyphilitica (33.41%)
# [Desert Dome 199/348] Ferocactus hystrix - top1=Ferocactus hystrix (97.96%) ✅
# [Desert Dome 200/348] Ferocactus pilosus - top1=Ferocactus pilosus (94.20%) ✅
# [Desert Dome 201/348] Ferocactus rectispinus - top1=Ferocactus hystrix (97.96%)
# [Desert Dome 202/348] Fouquieria fasciculata - top1=Fouquieria columnaris (89.36%)
# [Desert Dome 203/348] Fouquieria macdougalii - top1=Fouquieria columnaris (89.36%)
# [Desert Dome 204/348] Graptopetalum amethystinum - top1=Graptopetalum amethystinum (73.96%) ✅
# [Desert Dome 205/348] Graptopetalum paraguayense - top1=Echeveria multicaulis (31.17%)
# [Desert Dome 206/348] Hamatocactus hamatacanthus - top1=Ferocactus hystrix (53.39%)
# [Desert Dome 207/348] Leuchtenbergia principis - top1=Leuchtenbergia principis (54.95%) ✅
# [Desert Dome 208/348] Lophocereus schottii - top1=Lophocereus schottii (94.62%) ✅
# [Desert Dome 209/348] Mammillaria decipiens - top1=Mammillaria parkinsonii (38.30%)
# [Desert Dome 210/348] Mammillaria elongata - top1=Mammillaria elongata (91.21%) ✅
# [Desert Dome 211/348] Mammillaria geminispina - top1=Mammillaria geminispina (96.59%) ✅
# [Desert Dome 212/348] Mammillaria hahniana - top1=Mammillaria hahniana 'Super Clone' (42.22%)
# [Desert Dome 213/348] Mammillaria parkinsonii - top1=Mammillaria parkinsonii (94.92%) ✅
# [Desert Dome 214/348] Mammillaria petterssonii - top1=Mammillaria petterssonii (85.37%) ✅
# [Desert Dome 215/348] Mammillaria vetula - top1=Mammillaria vetula (92.93%) ✅
# [Desert Dome 216/348] Lophocereus marginatus - top1=Cereus sp. (61.37%)
# [Desert Dome 217/348] MYRTILLOCACTUS GEOMETRIZANS - no wiki image
# [Desert Dome 218/348] Cephalocereus polylophus - top1=Opuntia galapageia (31.22%)
# [Desert Dome 219/348] Opuntia aciculata - top1=Opuntia phaecantha (87.79%)
# [Desert Dome 220/348] Opuntia leucotricha - top1=Opuntia leucotricha (58.40%) ✅
# [Desert Dome 221/348] Opuntia microdasys - top1=Opuntia microdasys (96.40%) ✅
# [Desert Dome 222/348] Opuntia rufida - top1=Opuntia rufida (87.26%) ✅
# [Desert Dome 223/348] Opuntia robusta - top1=Opuntia robusta (99.09%) ✅
# [Desert Dome 224/348] Pachycereus pringlei - top1=Pachycereus pringlei (94.65%) ✅
# [Desert Dome 225/348] Pachycereus - top1=Pachycereus pringlei (74.10%)
# [Desert Dome 226/348] PACHYPHYTUM BRACTEOSUM - no wiki image
# [Desert Dome 227/348] Pinus maximartinezii - top1=Pinus maximartinezii (57.78%) ✅
# [Desert Dome 228/348] Sedum adolphii - top1=PACHYPHYTUM BRACTEOSUM (95.49%)
# [Desert Dome 229/348] Sedum morganianum - top1=Crassula ovata 'Hobbit' (69.06%)
# [Desert Dome 230/348] Fouquieria diguetii - top1=Fouquieria diguetii (99.09%) ✅
# [Desert Dome 231/348] Sideroxylon spinosum - top1=OPERCULicARyA dECARYI (67.67%)
# [Desert Dome 232/348] Cleistocactus hyalacanthus - top1=Cleistocactus baumannii (96.82%)
# [Desert Dome 233/348] Fouquieria splendens - top1=Fouquieria columnaris (79.54%)
# [Desert Dome 234/348] CEREUS FORBESII - no wiki image
# [Desert Dome 235/348] Adansonia madagascariensis - top1=Ficus benghalensis (94.26%)
# [Desert Dome 236/348] Ariocarpus fissuratus - top1=Gymnocalycium unknown (13.18%)
# [Desert Dome 237/348] Calliandra eriophylla - top1=Calliandra eriophylla (99.88%) ✅
# [Desert Dome 238/348] ADENIA SPINOSA - no wiki image
# [Desert Dome 239/348] Aloe alooides - top1=Aloe vaombe (36.04%)
# [Desert Dome 240/348] Aloe broomii - top1=Aloe maculata (34.70%)
# [Desert Dome 241/348] Aloe ferox - top1=Aloe ferox (31.32%) ✅
# [Desert Dome 242/348] Aloe humilis - top1=Agave stricta 'Nana' (40.83%)
# [Desert Dome 243/348] Aloe krapohliana - top1=Aloe vaombe (36.04%)
# [Desert Dome 244/348] Aloe marlothii - top1=Aloe sp. (23.86%)
# [Desert Dome 245/348] Aloe melanacantha - top1=Hohenbergia magnispina (21.56%)
# [Desert Dome 246/348] Aloe microstigma - top1=Aloe vaombe (36.04%)
# [Desert Dome 247/348] Aloe striata - top1=Crassula ovata (68.70%)
# [Desert Dome 248/348] Aloiampelos ciliaris - top1=Aloiampelos ciliaris (70.19%) ✅
# [Desert Dome 249/348] Boophane disticha - no wiki image
# [Desert Dome 250/348] Bowiea volubilis - top1=Cola acuminata (13.36%)
# [Desert Dome 251/348] Crassula arborescens - top1=Crassula ovata (91.93%)
# [Desert Dome 252/348] Crassula PERFORATA - top1=Neoregelia 'Fireball' (44.13%)
# [Desert Dome 253/348] Crassula - top1=Neoregelia 'Fireball' (44.13%)
# [Desert Dome 254/348] Crassula falcata - top1=Crassula ovata (49.03%)
# [Desert Dome 255/348] Crassula ovata - top1=Crassula ovata (99.85%) ✅
# [Desert Dome 256/348] Crassula ovata variegata - top1=Neoregelia 'Fireball' (44.13%)
# [Desert Dome 257/348] Cyphostemma juttae - top1=Astrophytum myriostigma (80.72%)
# [Desert Dome 258/348] Delosperma echinatum - top1=Opuntia microdasys (76.45%)
# [Desert Dome 259/348] Encephalartos ferox - top1=Encephalartos ferox (73.26%) ✅
# [Desert Dome 260/348] Encephalartos horridus - top1=Encephalartos horridus (99.94%) ✅
# [Desert Dome 261/348] Euphorbia horrida - top1=Euphorbia abyssinica (97.94%)
# [Desert Dome 262/348] Euphorbia obesa - top1=Parodia sp. (45.29%)
# [Desert Dome 263/348] Euphorbia zoutpansbergensis - top1=Euphorbia milii (69.82%)
# [Desert Dome 264/348] Faucaria tigrina - top1=Kalanchoe millotii (85.17%)
# [Desert Dome 265/348] Gasteria excelsa - top1=Aloe jucunda (77.40%)
# [Desert Dome 266/348] Haemanthus albiflos - top1=Haemanthus albiflos (99.76%) ✅
# [Desert Dome 267/348] Haworthia cymbiformis - top1=Haworthia cymbiformis (65.58%) ✅
# [Desert Dome 268/348] Haworthiopsis reinwardtii - top1=Agave victoriae-reginae (97.25%)
# [Desert Dome 269/348] Haworthiopsis tessellata - top1=Euphorbia platyclada (92.12%)
# [Desert Dome 270/348] Lithops geyeri - top1=Lithops geyeri (92.76%) ✅
# [Desert Dome 271/348] Lithops hookeri - top1=Lithops geyeri (50.30%)
# [Desert Dome 272/348] Pachypodium saundersii - top1=Euphorbia beharensis ? (91.36%)
# [Desert Dome 273/348] PORTULACARIA AFRA - no wiki image
# [Desert Dome 274/348] Portulacaria afra - top1=PORTULACARIA AFRA (94.45%)
# [Desert Dome 275/348] Curio ficoides - top1=Senecio crassissimus (42.04%)
# [Desert Dome 276/348] Kleinia stapeliiformis - top1=Alocasia micholitziana 'Frydek' (96.98%)
# [Desert Dome 277/348] Strelitzia juncea - top1=Strelitzia juncea (100.00%) ✅
# [Desert Dome 278/348] Tylecodon paniculatus - top1=Tylecodon paniculatus (90.82%) ✅
# [Desert Dome 279/348] Welwitschia mirabilis - top1=Welwitschia mirabilis (98.78%) ✅
# [Desert Dome 280/348] Begonia ruhlandiana - top1=Begonia coccinea (88.75%)
# [Desert Dome 281/348] Bromelia balansae - top1=Neoregelia 'Fireball' (60.24%)
# [Desert Dome 282/348] Cleistocactus baumannii - top1=Fouquieria formosa (84.25%)
# [Desert Dome 283/348] Cleistocactus samaipatanus - top1=Cleistocactus samaipatanus (40.27%) ✅
# [Desert Dome 284/348] Cleistocactus - top1=Mammillaria geminispina (62.61%)
# [Desert Dome 285/348] Copiapoa coquimbana - top1=Copiapoa coquimbana (42.96%) ✅
# [Desert Dome 286/348] Copiapoa echinoides - top1=Pachycereus pringlei (45.36%)
# [Desert Dome 287/348] Copiapoa hypogaea - top1=Gymnocalycium unknown (8.74%)
# [Desert Dome 288/348] Copiapoa lembeckei - top1=Cleistocactus sp. (77.57%)
# [Desert Dome 289/348] Dyckia - top1=Neoregelia 'Dragon' (30.74%)
# [Desert Dome 290/348] Echinopsis huascha - top1=Echinopsis huascha (94.56%) ✅
# [Desert Dome 291/348] Echinopsis - top1=Echinopsis oxygona (87.06%)
# [Desert Dome 292/348] Furcraea selloana - top1=Phoenix canariensis (36.84%)
# [Desert Dome 293/348] Gymnocalycium saglionis - top1=Echinopsis sp. (18.77%)
# [Desert Dome 294/348] Hippeastrum puniceum - top1=Hippeastrum puniceum (99.76%) ✅
# [Desert Dome 295/348] Hylocereus undatus - top1=Hylocereus undatus (77.37%) ✅
# [Desert Dome 296/348] Leucostele terscheckii - top1=Pilosocereus sp. (23.12%)
# [Desert Dome 297/348] Parodia magnifica - top1=Opuntia galapageia (15.93%)
# [Desert Dome 298/348] Parodia - top1=Euphorbia obesa (65.13%)
# [Desert Dome 299/348] OREOCEREUS - no wiki image
# [Desert Dome 300/348] Oreocereus trollii - top1=Oreocereus trollii (86.85%) ✅
# [Desert Dome 301/348] Pilosocereus - top1=Pilosocereus sp. (99.22%)
# [Desert Dome 302/348] Puya roezlii - no wiki image
# [Desert Dome 303/348] Ubelmannia pectinifera - no wiki image
# [Desert Dome 304/348] Aloe macrocarpa - top1=Aloe vaombe (36.04%)
# [Desert Dome 305/348] Aloidendron dichotomum - top1=Aloidendron dichotomum (96.94%) ✅
# [Desert Dome 306/348] Dracaena hallii - top1=Encephalartos horridus (47.09%)
# [Desert Dome 307/348] Euphorbia grandidens - top1=Euphorbia zoutpansbergensis (56.16%)
# [Desert Dome 308/348] Fockea edulis - top1=Kalanchoe hildebrandtii (19.51%)
# [Desert Dome 309/348] Haworthiopsis limifolia - top1=Haworthiopsis limifolia (58.70%) ✅
# [Desert Dome 310/348] Echinopsis oxygona - top1=Echinopsis oxygona (61.02%) ✅
# [Desert Dome 311/348] Parodia leninghausii - top1=Parodia leninghausii (98.93%) ✅
# [Desert Dome 312/348] PACHYPODIUM BARONII - no wiki image
# [Desert Dome 313/348] Hemionitis bradburyi - top1=Adiantum raddianum (57.29%)
# [Desert Dome 314/348] Pelargonium carnosum - top1=Catharanthus roseus (31.83%)
# [Desert Dome 315/348] Alluaudia COMOSA - top1=Fouquieria splendens (46.08%)
# [Desert Dome 316/348] Alluaudia dumosa - top1=Fouquieria splendens (46.08%)
# [Desert Dome 317/348] Alluaudia humbertii - top1=Fouquieria columnaris (55.19%)
# [Desert Dome 318/348] Alluaudia montagnacii - top1=Euphorbia tirucalli (38.24%)
# [Desert Dome 319/348] Didierea madagascariensis - top1=Euphorbia tirucalli (75.92%)
# [Desert Dome 320/348] Euphorbia beharensis ? - top1=Adenia sp. (53.10%)
# [Desert Dome 321/348] Hesperaloe parviflora - top1=Agave lechuguilla (91.57%)
# [Desert Dome 322/348] Yucca baccata - top1=Yucca baccata (97.16%) ✅
# [Desert Dome 323/348] Yucca rostrata - top1=Yucca elata (76.96%)
# [Desert Dome 324/348] PACHYPODIUM GEAYI - no wiki image
# [Desert Dome 325/348] Berberis haematocarpa - top1=Euphorbia beharensis ? (91.20%)
# [Desert Dome 326/348] Ephedra nevadensis - top1=Ephedra nevadensis (96.57%) ✅
# [Desert Dome 327/348] Leucophyllum frutescens - top1=Leucophyllum frutescens (99.54%) ✅
# [Desert Dome 328/348] Agave lechuguilla - top1=Agave lechuguilla (21.37%) ✅
# [Desert Dome 329/348] Bursera hindsiana - top1=Bursera microphylla (74.98%)
# [Desert Dome 330/348] Bursera microphylla - top1=Cassia artemisioides (71.87%)
# [Desert Dome 331/348] Cylindropuntia - top1=Kalanchoe beharensis (30.86%)
# [Desert Dome 332/348] Larrea tridentata - top1=Larrea tridentata (100.00%) ✅
# [Desert Dome 333/348] Opuntia phaecantha - top1=Alpinia zerumbet (18.24%)
# [Desert Dome 334/348] Opuntia santa-rita - top1=Opuntia phaecantha (76.02%)
# [Desert Dome 335/348] Rhus ovata - top1=Cyrtomium falcatum (53.64%)
# [Desert Dome 336/348] Simmondsia chinensis - top1=Simmondsia chinensis (95.51%) ✅
# [Desert Dome 337/348] Ferocactus wislizeni - top1=Echinopsis sp. (29.73%)
# [Desert Dome 338/348] Yucca faxoniana - top1=Yucca elata (62.65%)
# [Desert Dome 339/348] Echinocereus - top1=Ferocactus wislizeni (81.73%)
# [Desert Dome 340/348] Opuntia basilaris - top1=Kalanchoe beharensis 'Fang' (26.03%)
# [Desert Dome 341/348] Opuntia basilaris hyb. - top1=Opuntia robusta (42.41%)
# [Desert Dome 342/348] Agave parrasana - top1=Agave toumeyana (52.87%)
# [Desert Dome 343/348] Chilopsis linearis - top1=Mansoa alliacea (53.49%)
# [Desert Dome 344/348] Salvia apiana - top1=Mammillaria geminispina (77.04%)
# [Desert Dome 345/348] Nolina lindheimeriana - top1=Yucca rostrata (37.47%)
# [Desert Dome 346/348] YUCCA carnerosana - no wiki image
# [Desert Dome 347/348] Euphorbia antisyphilitica - top1=Euphorbia antisyphilitica (99.99%) ✅
# [Desert Dome 348/348] Euphorbia milii - top1=Euphorbia milii (99.60%) ✅
# Skipping combined dome 'All' (per-dome evaluations performed)
#
# Done. Results saved to data/bioclip_wikipedia_eval.csv. Elapsed: 190.3s
#
# Summary:
#   total_species_evaluated: 724
#   total_with_images: 677
#   species_top1_count: 191
#   species_top3_count: 248
#   species_top5_count: 277
#   species_top1_acc: 0.282
#   species_top3_acc: 0.366
#   species_top5_acc: 0.409
#   genus_top1_count: 347
#   genus_top3_count: 448
#   genus_top5_count: 479
#   genus_top1_acc: 0.513
#   genus_top3_acc: 0.662
#   genus_top5_acc: 0.708
#   per_dome:
#     Desert Dome: count_with_images=311, species_top1_acc=0.260, genus_top1_acc=0.547
#     Tropical Dome: count_with_images=366, species_top1_acc=0.301, genus_top1_acc=0.484
#   confidence_bins:
#     <0.6: count=317, species_top1_acc=0.126, genus_top1_acc=0.372
#     0.6-0.7: count=52, species_top1_acc=0.135, genus_top1_acc=0.288
#     0.7-0.8: count=73, species_top1_acc=0.301, genus_top1_acc=0.521
#     0.8-0.9: count=56, species_top1_acc=0.268, genus_top1_acc=0.571
#     >=0.9: count=179, species_top1_acc=0.598, genus_top1_acc=0.804

# %%
# Preview a few rows from the saved CSV
r = pd.read_csv('data/bioclip_wikipedia_eval.csv')
r.head()
# Out:
#             plant_name           Dome  found_image  \
# 0     Acalypha hispida  Tropical Dome         True
# 1       Acca selloiana  Tropical Dome        False
# 2         Achimenantha  Tropical Dome        False
# 3  Adiantum peruvianum  Tropical Dome         True
# 4   Adiantum raddianum  Tropical Dome         True
#
#                                            thumbnail                top_1  \
# 0  https://upload.wikimedia.org/wikipedia/commons...     Acalypha hispida
# 1                                                NaN                  NaN
# 2                                                NaN                  NaN
# 3  https://upload.wikimedia.org/wikipedia/commons...  Adiantum peruvianum
# 4  https://upload.wikimedia.org/wikipedia/commons...   Adiantum raddianum
#
#    top_1_conf                                              top_5 fetch_method  \
# 0    0.999946  [('Acalypha hispida', 0.9999463558197021), ('C...        batch
# 1    0.000000                                                 []          NaN
# 2    0.000000                                                 []          NaN
# 3    0.999834  [('Adiantum peruvianum', 0.9998335838317871), ...        batch
# 4    0.756429  [('Adiantum raddianum', 0.7564293742179871), (...        batch
#
#    top1_species_match  top3_species_match  top5_species_match  \
# 0                True                True                True
# 1               False               False               False
# 2               False               False               False
# 3                True                True                True
# 4                True                True                True
#
#    top1_genus_match  top3_genus_match  top5_genus_match
# 0              True              True              True
# 1             False             False             False
# 2             False             False             False
# 3              True              True              True
# 4              True              True              True
